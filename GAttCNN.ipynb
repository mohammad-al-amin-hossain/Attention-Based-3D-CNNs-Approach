# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import KFold,train_test_split, StratifiedKFold
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
from torch.nn import functional as F
import torchvision
from torchvision import datasets,transforms
import torchvision.transforms as transforms

from PIL import Image
import pandas as pd 
import math

import scipy.io

import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
torch.cuda.is_available()
# Out:
# True

# %%
df=pd.read_excel('D:/Hossam/h/Video_classification.xlsx')
data_dir='D:/Hossam/h/VideoData_trimmed'

classification = np.where(df.Classification == 'Benign' , 0, 1)
df['Class_Type'] = classification

class CEUS_Dataset(Dataset):
    def __init__ (self,df, train:bool = True):
        self.df=df
        self.train=train
        
    def __getitem__(self,index):
        pat_name=self.df['Pat_code'].iloc[index]
        filename=data_dir+'/'+pat_name+'.mat'
        # loading mat file
        mat = scipy.io.loadmat(filename)
        
        c=mat['xceus_red']
        #resizeing images
        x = transforms.ToTensor()(c)
        x = transforms.Resize(300)(x)
        #changing type to float
        x=x.unsqueeze(0).type(torch.FloatTensor)

        if(self.train):
            y= self.df['Class_Type'].iloc[index]
            
            return x,y
        else:
            y= self.df['Class_Type'].iloc[index]
            return y
        
    def __len__(self):
        return len (self.df)
    

####dataloder

# df_train, df_test = train_test_split(df)

# train_dataset=CEUS_Dataset(
#    df=df_train,
#    train=True,
# )

# train_loader=DataLoader(
#    train_dataset,
#    batch_size=3,
#    shuffle=True,
#    drop_last=True,
# )


# test_dataset=CEUS_Dataset(
#    df=df_test,
#    train=True,
# )

# test_loader=DataLoader(
#    test_dataset,
#    batch_size=3,
#    shuffle=False,
#    drop_last=True,
# )
# m=len(train_dataset)

# images, labels=next(iter(train_loader))
# # print (images.shape)

# %%
class GAB_3D(nn.Module):
    def __init__(self, in_channels, g_c, i_c):
        super(GAB_3D, self).__init__()
        
        self.in_channels = in_channels
        self.g_c = g_c
        self.i_c = i_c
        
        conv = nn.Conv3d
        bn = nn.BatchNorm3d
                
        self.norm1 = lambda x: x
        
        
        self.W = nn.Sequential(
            conv(in_channels=self.in_channels, out_channels=self.in_channels, kernel_size=1, stride=1, padding=0),
            bn(self.in_channels),
        )
   
        self.theta = conv(in_channels=self.in_channels, out_channels=self.i_c, kernel_size=(1,1,1), 
                          stride=(1,1,1), padding=0, bias=False)
        
        self.phi = conv(in_channels=self.g_c, out_channels=self.i_c, 
                        kernel_size=(1,1,1), stride=(1,1,1), padding=0, bias=False)
        self.psi = conv(in_channels=self.i_c, out_channels=1, kernel_size=1, stride=1, padding=0, bias=True)

        self.norm1 = lambda x: F.relu(x, inplace=True)
        
        self.o_f = self.joining
        
        nn.init.constant_(self.psi.bias.data, 3.0)


    def forward(self, x, g):
        
        output = self.o_f(x, g)
        return output

    def joining (self, x, g):
        x_size = x.size()
        batch_size = x_size[0]
        assert batch_size == g.size(0)

        theta_x = self.theta(x)
        theta_x_size = theta_x.size()

        phi_g = F.interpolate(self.phi(g), size=theta_x_size[2:], mode='trilinear')
        
        f = theta_x + phi_g
        f = self.norm1(f)

        psi_f = self.psi(f)
        
        sigm_psi_f = torch.sigmoid(psi_f)


        sigm_psi_f = F.interpolate(sigm_psi_f, size = x_size[2:], mode='trilinear')
        
        y = sigm_psi_f.expand_as(x) * x
        W_y = self.W(y)

        return W_y, sigm_psi_f


class UnetConv3D(nn.Module):
    def __init__(self, in_size, out_size, kernel_size=(1,3,3), padding_size=(0,1,1), init_stride=(1,1,1)):
        super(UnetConv3D, self).__init__()
        
        self.conv1 = nn.Sequential(nn.Conv3d(in_size, out_size, kernel_size, init_stride, padding_size), 
                                   nn.ReLU(inplace=True),
                                   nn.Conv3d(out_size, out_size, kernel_size, 1, padding_size), 
                                   nn.ReLU(inplace=True),
                                   nn.BatchNorm3d(out_size), nn.ReLU(inplace=True),)

    def forward(self, x):
        x = self.conv1(x)
        return x

# %%
class Unet_grid_attention(nn.Module):

    def __init__(self):
        super(Unet_grid_attention, self).__init__()
        self.in_channels = 1
        
        feature = 4
        n_classes = 2
        
        

        filters = [64, 128, 256, 512]
        filters = [int(x / feature) for x in filters]
        
        
        self.conv1 = UnetConv3D(self.in_channels, filters[0])
        self.maxpool1 = nn.MaxPool3d(kernel_size=2)

        #self.conv2 = UnetConv3D(filters[0], filters[1])
        #self.maxpool2 = nn.MaxPool3d(kernel_size=2)

        self.conv3 = UnetConv3D(filters[0], filters[2])
        self.maxpool3 = nn.MaxPool3d(kernel_size=2)

        self.conv4 = UnetConv3D(filters[2], filters[3])
        self.maxpool4 = nn.MaxPool3d(kernel_size=2)

        self.conv5 = UnetConv3D(filters[3], filters[3])

        # Attention Maps
        
        
        self.c_s1 = GAB_3D(in_channels=filters[2], g_c=filters[3], i_c=filters[3])

        self.c_s2 = GAB_3D(in_channels=filters[3], g_c=filters[3], i_c=filters[3])
        
        self.relu = nn.ReLU()

        
        # Aggreagation Strategies
        
        self.att_f = [filters[2], filters[3]]

        self.classifier = nn.Linear(filters[2]+filters[3]+filters[3], n_classes)
        
        self.cluster = self.cluster_cat
        
        
        
    def cluster_cat(self, *attended_maps):
        return self.classifier(torch.cat(attended_maps, dim=1))


    def forward(self, x):
        # Feature Extraction
        conv1 = self.conv1(x)
        maxpool1 = self.maxpool1(conv1)

        #conv2 = self.conv2(maxpool1)
        #maxpool2 = self.maxpool2(conv2)

        conv3 = self.conv3(maxpool1)
        maxpool3 = self.maxpool3(conv3)
        

        conv4 = self.conv4(maxpool3)
        maxpool4 = self.maxpool4(conv4)

        conv5 = self.conv5(maxpool4)

        b_s = x.shape[0]
        pooled = F.adaptive_avg_pool3d(conv5, (1, 1, 1)).view(b_s, -1)
        

        # Attention Mechanism
        g_conv1, att1 = self.c_s1(conv3, conv5)
        
        g_conv2, att2 = self.c_s2(conv4, conv5)
        
        

        # flatten to get single feature vector
        f_s = self.att_f
        g1 = torch.sum(g_conv1.view(b_s, f_s[0], -1), dim=-1)
        
        g2 = torch.sum(g_conv2.view(b_s, f_s[1], -1), dim=-1)
        
        #print("j")
        return self.cluster(g1, g2, pooled)

    
model = Unet_grid_attention()

# %%
device = torch.device('cuda:0')

def train_epoch(model,dataloader,loss_fn,optimizer): 
    model=model.to(device)
    train_loss,train_correct=0.0,0
    model.train()

    for images, labels in dataloader:
        labels=labels.type(torch.LongTensor).to(device)
        images=images.to(device)
        
        with torch.set_grad_enabled(True):
            optimizer.zero_grad()
            output = model(images)
            loss = loss_fn(output,labels)
            loss.backward()
            optimizer.step()   
            
        train_loss += loss.item() * images.size(0)
        scores, predictions = torch.max(output.data, 1)
        train_correct += (predictions == labels).sum().item()
        
    return train_loss, train_correct

# %%
def test_epoch(model,dataloader,loss_fn):
    model=model.to(device)
    test_loss, test_correct = 0.0, 0
    model.eval()
    confusion_matrix = torch.zeros(2, 2)
    for images, labels in dataloader:
        labels=labels.type(torch.LongTensor).to(device)
        images=images.to(device)
        
        with torch.set_grad_enabled(False):
            output = model(images)
            loss=loss_fn(output,labels)

            test_loss+=loss.item()*images.size(0)
        scores, predictions = torch.max(output.data,1)
        test_correct+=(predictions == labels).sum().item()
        for t, p in zip(labels.view(-1), predictions.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

    return test_loss,test_correct,confusion_matrix

# %%
# Model name = GAttCNN_K5F


b_s=3

device = torch.device('cuda:0')


error = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)


dataset=CEUS_Dataset(df, train=True)


num_epochs=50

k=5
splits=KFold(n_splits=k,shuffle=True,random_state=42)

foldperf={}


for fold, (train_x,test_x) in enumerate(splits.split(np.arange(len(dataset)))):

    print('Fold Number{}'.format(fold + 1))

    train_sampler = SubsetRandomSampler(train_x)
    test_sampler = SubsetRandomSampler(test_x)
    trainLoader = torch.utils.data.DataLoader(dataset, batch_size=b_s,  sampler=train_sampler)
    testLoader = torch.utils.data.DataLoader(dataset, batch_size=b_s, sampler=test_sampler)
    
    model = Unet_grid_attention()
    
    
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    

    l_a = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

    for epoch in range(num_epochs):
        
        train_loss, train_correct=train_epoch(model,trainLoader,error,optimizer)
        test_loss, test_correct,e=test_epoch(model,testLoader,error)

        train_loss = train_loss / len(trainLoader.sampler)
        train_acc = train_correct / len(trainLoader.sampler) * 100
        test_loss = test_loss / len(testLoader.sampler)
        test_acc = test_correct / len(testLoader.sampler) * 100

        print("Epoch:{}/{} Train_Loss:{:.2f} Test_Loss:{:.2f} Train_Acc {:.2f} % Test_Acc {:.2f} %".format(epoch + 1, 
                                                                                                       num_epochs, 
                                                                                                       train_loss, 
                                                                                                       test_loss, 
                                                                                                       train_acc, 
                                                                                                       test_acc))
        
        #train_loss, train_correct=train_epoch(model,train_loader,error,optimizer)
        #test_loss, test_correct,e=test_epoch(model,test_loader,error)

        l_a['train_loss'].append(train_loss)
        l_a['test_loss'].append(test_loss)
        l_a['train_acc'].append(train_acc)
        l_a['test_acc'].append(test_acc)
        
    plt.figure(figsize=(5,5))    
    test_loss, test_correct,e=test_epoch(model,testLoader,error)
    df_cm = pd.DataFrame(e, index=["Benign", "Malignant"], columns=["Benign", "Malignant"]).astype(int)
    heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
        

    foldperf['fold{}'.format(fold+1)] = l_a
# Out:
# Fold Number1
# Epoch:1/50 Train_Loss:19072.24 Test_Loss:78814.44 Train_Acc 58.33 % Test_Acc 11.11 %
# Epoch:2/50 Train_Loss:5063.05 Test_Loss:2868.62 Train_Acc 41.67 % Test_Acc 77.78 %
# Epoch:3/50 Train_Loss:2962.74 Test_Loss:9969.68 Train_Acc 58.33 % Test_Acc 11.11 %
# Epoch:4/50 Train_Loss:2713.23 Test_Loss:19042.51 Train_Acc 50.00 % Test_Acc 11.11 %
# Epoch:5/50 Train_Loss:2723.21 Test_Loss:18119.55 Train_Acc 61.11 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:4245.50 Test_Loss:1233.64 Train_Acc 61.11 % Test_Acc 77.78 %
# Epoch:7/50 Train_Loss:2458.85 Test_Loss:1642.66 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:8/50 Train_Loss:2133.14 Test_Loss:341.79 Train_Acc 52.78 % Test_Acc 88.89 %
# Epoch:9/50 Train_Loss:1276.27 Test_Loss:515.87 Train_Acc 72.22 % Test_Acc 77.78 %
# Epoch:10/50 Train_Loss:2022.42 Test_Loss:25785.12 Train_Acc 61.11 % Test_Acc 11.11 %
# Epoch:11/50 Train_Loss:1145.08 Test_Loss:10175.16 Train_Acc 63.89 % Test_Acc 11.11 %
# Epoch:12/50 Train_Loss:1940.22 Test_Loss:9355.89 Train_Acc 55.56 % Test_Acc 11.11 %
# Epoch:13/50 Train_Loss:2769.65 Test_Loss:1155.88 Train_Acc 47.22 % Test_Acc 66.67 %
# Epoch:14/50 Train_Loss:2023.51 Test_Loss:8510.24 Train_Acc 55.56 % Test_Acc 11.11 %
# Epoch:15/50 Train_Loss:1777.83 Test_Loss:2830.56 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:16/50 Train_Loss:1919.36 Test_Loss:1138.37 Train_Acc 52.78 % Test_Acc 77.78 %
# Epoch:17/50 Train_Loss:1468.85 Test_Loss:8194.98 Train_Acc 69.44 % Test_Acc 22.22 %
# Epoch:18/50 Train_Loss:1418.52 Test_Loss:17485.35 Train_Acc 66.67 % Test_Acc 22.22 %
# Epoch:19/50 Train_Loss:2733.49 Test_Loss:3280.43 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:20/50 Train_Loss:2170.53 Test_Loss:1131.44 Train_Acc 47.22 % Test_Acc 66.67 %
# Epoch:21/50 Train_Loss:814.92 Test_Loss:438.01 Train_Acc 61.11 % Test_Acc 88.89 %
# Epoch:22/50 Train_Loss:1005.08 Test_Loss:0.00 Train_Acc 61.11 % Test_Acc 100.00 %
# Epoch:23/50 Train_Loss:882.27 Test_Loss:4826.15 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:24/50 Train_Loss:548.00 Test_Loss:5416.97 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:25/50 Train_Loss:705.21 Test_Loss:2811.11 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:26/50 Train_Loss:932.25 Test_Loss:1599.06 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:750.18 Test_Loss:12317.62 Train_Acc 75.00 % Test_Acc 11.11 %
# Epoch:28/50 Train_Loss:876.66 Test_Loss:1295.91 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:29/50 Train_Loss:1112.63 Test_Loss:4322.44 Train_Acc 66.67 % Test_Acc 11.11 %
# Epoch:30/50 Train_Loss:616.17 Test_Loss:6913.62 Train_Acc 75.00 % Test_Acc 11.11 %
# Epoch:31/50 Train_Loss:1380.62 Test_Loss:2458.18 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:32/50 Train_Loss:1536.44 Test_Loss:9903.96 Train_Acc 63.89 % Test_Acc 22.22 %
# Epoch:33/50 Train_Loss:1000.87 Test_Loss:2257.74 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:34/50 Train_Loss:1627.39 Test_Loss:13710.12 Train_Acc 55.56 % Test_Acc 11.11 %
# Epoch:35/50 Train_Loss:1151.63 Test_Loss:609.70 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:36/50 Train_Loss:653.21 Test_Loss:505.52 Train_Acc 66.67 % Test_Acc 77.78 %
# Epoch:37/50 Train_Loss:281.39 Test_Loss:1918.61 Train_Acc 75.00 % Test_Acc 22.22 %
# Epoch:38/50 Train_Loss:427.03 Test_Loss:1048.80 Train_Acc 63.89 % Test_Acc 33.33 %
# Epoch:39/50 Train_Loss:929.26 Test_Loss:10117.56 Train_Acc 63.89 % Test_Acc 11.11 %
# Epoch:40/50 Train_Loss:1191.42 Test_Loss:1074.58 Train_Acc 63.89 % Test_Acc 33.33 %
# Epoch:41/50 Train_Loss:479.05 Test_Loss:1196.05 Train_Acc 69.44 % Test_Acc 88.89 %
# Epoch:42/50 Train_Loss:618.96 Test_Loss:614.11 Train_Acc 69.44 % Test_Acc 88.89 %
# Epoch:43/50 Train_Loss:492.31 Test_Loss:2943.67 Train_Acc 77.78 % Test_Acc 11.11 %
# Epoch:44/50 Train_Loss:242.77 Test_Loss:980.55 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:45/50 Train_Loss:706.95 Test_Loss:810.73 Train_Acc 52.78 % Test_Acc 44.44 %
# Epoch:46/50 Train_Loss:559.35 Test_Loss:804.25 Train_Acc 72.22 % Test_Acc 88.89 %
# Epoch:47/50 Train_Loss:495.21 Test_Loss:2893.65 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:48/50 Train_Loss:1069.05 Test_Loss:761.95 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:49/50 Train_Loss:571.93 Test_Loss:161.59 Train_Acc 55.56 % Test_Acc 66.67 %
# Epoch:50/50 Train_Loss:245.80 Test_Loss:1090.68 Train_Acc 69.44 % Test_Acc 44.44 %
# Fold Number2
# Epoch:1/50 Train_Loss:12888.57 Test_Loss:13983.15 Train_Acc 55.56 % Test_Acc 44.44 %
# Epoch:2/50 Train_Loss:9564.99 Test_Loss:9038.42 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:3/50 Train_Loss:4412.10 Test_Loss:9527.31 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:4/50 Train_Loss:3476.41 Test_Loss:10215.10 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:5/50 Train_Loss:1397.84 Test_Loss:5193.16 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:6/50 Train_Loss:2264.10 Test_Loss:3228.28 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:7/50 Train_Loss:1322.83 Test_Loss:2556.56 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:8/50 Train_Loss:1682.98 Test_Loss:3576.69 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:9/50 Train_Loss:1060.11 Test_Loss:2499.85 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:10/50 Train_Loss:1249.85 Test_Loss:173.75 Train_Acc 58.33 % Test_Acc 77.78 %
# Epoch:11/50 Train_Loss:1101.92 Test_Loss:1481.19 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:12/50 Train_Loss:1640.27 Test_Loss:4541.52 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:13/50 Train_Loss:1064.22 Test_Loss:4185.58 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:14/50 Train_Loss:1096.23 Test_Loss:524.51 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:15/50 Train_Loss:561.58 Test_Loss:1339.63 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:16/50 Train_Loss:1022.03 Test_Loss:977.50 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:17/50 Train_Loss:588.90 Test_Loss:882.67 Train_Acc 55.56 % Test_Acc 55.56 %
# Epoch:18/50 Train_Loss:722.35 Test_Loss:679.43 Train_Acc 61.11 % Test_Acc 77.78 %
# Epoch:19/50 Train_Loss:482.38 Test_Loss:1135.77 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:20/50 Train_Loss:699.73 Test_Loss:2103.63 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:21/50 Train_Loss:612.53 Test_Loss:798.41 Train_Acc 63.89 % Test_Acc 77.78 %
# Epoch:22/50 Train_Loss:883.35 Test_Loss:740.10 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:23/50 Train_Loss:733.88 Test_Loss:1366.35 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:24/50 Train_Loss:344.98 Test_Loss:2670.14 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:25/50 Train_Loss:758.76 Test_Loss:737.87 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:26/50 Train_Loss:588.51 Test_Loss:1178.19 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:444.37 Test_Loss:1261.82 Train_Acc 80.56 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:668.35 Test_Loss:1130.44 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:29/50 Train_Loss:288.60 Test_Loss:413.38 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:30/50 Train_Loss:572.95 Test_Loss:1177.21 Train_Acc 69.44 % Test_Acc 77.78 %
# Epoch:31/50 Train_Loss:595.24 Test_Loss:1907.51 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:32/50 Train_Loss:369.08 Test_Loss:2996.05 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:33/50 Train_Loss:227.85 Test_Loss:759.11 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:34/50 Train_Loss:178.59 Test_Loss:421.31 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:35/50 Train_Loss:227.66 Test_Loss:135.49 Train_Acc 80.56 % Test_Acc 66.67 %
# Epoch:36/50 Train_Loss:295.39 Test_Loss:725.25 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:37/50 Train_Loss:289.79 Test_Loss:472.73 Train_Acc 63.89 % Test_Acc 33.33 %
# Epoch:38/50 Train_Loss:197.97 Test_Loss:973.94 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:39/50 Train_Loss:334.90 Test_Loss:927.67 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:40/50 Train_Loss:345.19 Test_Loss:729.45 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:41/50 Train_Loss:145.96 Test_Loss:418.19 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:42/50 Train_Loss:41.82 Test_Loss:541.20 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:43/50 Train_Loss:129.02 Test_Loss:747.21 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:44/50 Train_Loss:174.24 Test_Loss:422.98 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:45/50 Train_Loss:214.07 Test_Loss:484.24 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:169.03 Test_Loss:319.88 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:47/50 Train_Loss:152.83 Test_Loss:453.52 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:48/50 Train_Loss:82.84 Test_Loss:487.15 Train_Acc 75.00 % Test_Acc 77.78 %
# Epoch:49/50 Train_Loss:114.70 Test_Loss:649.57 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:50/50 Train_Loss:163.62 Test_Loss:326.93 Train_Acc 75.00 % Test_Acc 44.44 %
# Fold Number3
# Epoch:1/50 Train_Loss:13400.59 Test_Loss:2481.95 Train_Acc 41.67 % Test_Acc 55.56 %
# Epoch:2/50 Train_Loss:4654.23 Test_Loss:30477.37 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:3/50 Train_Loss:5024.63 Test_Loss:1748.67 Train_Acc 50.00 % Test_Acc 44.44 %
# Epoch:4/50 Train_Loss:3017.84 Test_Loss:6789.34 Train_Acc 47.22 % Test_Acc 77.78 %
# Epoch:5/50 Train_Loss:2210.10 Test_Loss:1904.95 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:6/50 Train_Loss:1153.37 Test_Loss:3453.77 Train_Acc 55.56 % Test_Acc 55.56 %
# Epoch:7/50 Train_Loss:878.22 Test_Loss:1715.62 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:8/50 Train_Loss:1292.01 Test_Loss:1761.34 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:9/50 Train_Loss:1507.09 Test_Loss:543.59 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:10/50 Train_Loss:1079.36 Test_Loss:2049.14 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:11/50 Train_Loss:705.87 Test_Loss:1247.40 Train_Acc 61.11 % Test_Acc 33.33 %
# Epoch:12/50 Train_Loss:935.22 Test_Loss:516.59 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:13/50 Train_Loss:395.27 Test_Loss:1200.11 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:14/50 Train_Loss:626.76 Test_Loss:706.61 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:15/50 Train_Loss:828.52 Test_Loss:613.02 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:16/50 Train_Loss:620.81 Test_Loss:1743.54 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:17/50 Train_Loss:945.22 Test_Loss:651.41 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:18/50 Train_Loss:1018.04 Test_Loss:1154.34 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:19/50 Train_Loss:657.79 Test_Loss:1067.33 Train_Acc 55.56 % Test_Acc 22.22 %
# Epoch:20/50 Train_Loss:648.27 Test_Loss:754.51 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:21/50 Train_Loss:706.62 Test_Loss:2536.71 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:22/50 Train_Loss:710.46 Test_Loss:1869.07 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:23/50 Train_Loss:972.02 Test_Loss:1492.76 Train_Acc 55.56 % Test_Acc 44.44 %
# Epoch:24/50 Train_Loss:1025.16 Test_Loss:596.74 Train_Acc 44.44 % Test_Acc 55.56 %
# Epoch:25/50 Train_Loss:986.11 Test_Loss:630.01 Train_Acc 55.56 % Test_Acc 33.33 %
# Epoch:26/50 Train_Loss:847.24 Test_Loss:2083.86 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:633.54 Test_Loss:749.50 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:28/50 Train_Loss:234.66 Test_Loss:308.91 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:29/50 Train_Loss:114.82 Test_Loss:326.11 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:30/50 Train_Loss:267.26 Test_Loss:926.87 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:446.50 Test_Loss:287.52 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:32/50 Train_Loss:318.26 Test_Loss:406.09 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:33/50 Train_Loss:323.41 Test_Loss:746.81 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:34/50 Train_Loss:157.34 Test_Loss:563.93 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:35/50 Train_Loss:346.58 Test_Loss:412.40 Train_Acc 47.22 % Test_Acc 66.67 %
# Epoch:36/50 Train_Loss:520.56 Test_Loss:414.70 Train_Acc 55.56 % Test_Acc 66.67 %
# Epoch:37/50 Train_Loss:338.35 Test_Loss:186.17 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:38/50 Train_Loss:382.72 Test_Loss:173.66 Train_Acc 66.67 % Test_Acc 77.78 %
# Epoch:39/50 Train_Loss:181.48 Test_Loss:1052.57 Train_Acc 55.56 % Test_Acc 55.56 %
# Epoch:40/50 Train_Loss:268.39 Test_Loss:260.19 Train_Acc 63.89 % Test_Acc 77.78 %
# Epoch:41/50 Train_Loss:276.96 Test_Loss:972.21 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:42/50 Train_Loss:555.67 Test_Loss:976.26 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:43/50 Train_Loss:371.62 Test_Loss:189.94 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:44/50 Train_Loss:334.64 Test_Loss:624.85 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:45/50 Train_Loss:225.06 Test_Loss:1271.74 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:46/50 Train_Loss:345.80 Test_Loss:197.06 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:47/50 Train_Loss:228.31 Test_Loss:164.68 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:48/50 Train_Loss:223.94 Test_Loss:822.63 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:520.78 Test_Loss:1084.78 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:50/50 Train_Loss:151.54 Test_Loss:595.63 Train_Acc 83.33 % Test_Acc 66.67 %
# Fold Number4
# Epoch:1/50 Train_Loss:14164.39 Test_Loss:5014.23 Train_Acc 47.22 % Test_Acc 66.67 %
# Epoch:2/50 Train_Loss:3432.52 Test_Loss:1916.01 Train_Acc 50.00 % Test_Acc 66.67 %
# Epoch:3/50 Train_Loss:1749.65 Test_Loss:8102.79 Train_Acc 63.89 % Test_Acc 33.33 %
# Epoch:4/50 Train_Loss:1433.52 Test_Loss:2440.70 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:5/50 Train_Loss:1807.65 Test_Loss:7027.76 Train_Acc 44.44 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:2065.74 Test_Loss:3997.99 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:7/50 Train_Loss:1422.11 Test_Loss:1857.50 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:8/50 Train_Loss:785.27 Test_Loss:535.04 Train_Acc 61.11 % Test_Acc 77.78 %
# Epoch:9/50 Train_Loss:398.42 Test_Loss:561.74 Train_Acc 72.22 % Test_Acc 77.78 %
# Epoch:10/50 Train_Loss:825.69 Test_Loss:696.12 Train_Acc 55.56 % Test_Acc 66.67 %
# Epoch:11/50 Train_Loss:670.44 Test_Loss:1218.87 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:12/50 Train_Loss:262.09 Test_Loss:2011.33 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:13/50 Train_Loss:270.20 Test_Loss:2878.94 Train_Acc 63.89 % Test_Acc 33.33 %
# Epoch:14/50 Train_Loss:319.58 Test_Loss:7263.59 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:15/50 Train_Loss:653.38 Test_Loss:0.00 Train_Acc 66.67 % Test_Acc 100.00 %
# Epoch:16/50 Train_Loss:1325.94 Test_Loss:5378.72 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:17/50 Train_Loss:776.96 Test_Loss:1282.23 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:18/50 Train_Loss:1198.50 Test_Loss:305.77 Train_Acc 58.33 % Test_Acc 77.78 %
# Epoch:19/50 Train_Loss:497.42 Test_Loss:74.07 Train_Acc 69.44 % Test_Acc 88.89 %
# Epoch:20/50 Train_Loss:308.25 Test_Loss:55.71 Train_Acc 58.33 % Test_Acc 88.89 %
# Epoch:21/50 Train_Loss:147.67 Test_Loss:199.00 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:22/50 Train_Loss:223.45 Test_Loss:264.47 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:23/50 Train_Loss:252.27 Test_Loss:82.71 Train_Acc 63.89 % Test_Acc 88.89 %
# Epoch:24/50 Train_Loss:274.24 Test_Loss:247.36 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:25/50 Train_Loss:148.11 Test_Loss:99.97 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:26/50 Train_Loss:118.55 Test_Loss:217.87 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:27/50 Train_Loss:221.73 Test_Loss:447.51 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:360.47 Test_Loss:303.51 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:29/50 Train_Loss:186.12 Test_Loss:447.61 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:30/50 Train_Loss:341.97 Test_Loss:211.80 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:201.18 Test_Loss:161.68 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:32/50 Train_Loss:90.39 Test_Loss:82.81 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:33/50 Train_Loss:149.67 Test_Loss:523.08 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:34/50 Train_Loss:216.51 Test_Loss:236.37 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:35/50 Train_Loss:214.93 Test_Loss:39.20 Train_Acc 72.22 % Test_Acc 88.89 %
# Epoch:36/50 Train_Loss:231.96 Test_Loss:509.93 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:37/50 Train_Loss:103.57 Test_Loss:131.39 Train_Acc 77.78 % Test_Acc 77.78 %
# Epoch:38/50 Train_Loss:146.06 Test_Loss:560.37 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:39/50 Train_Loss:143.16 Test_Loss:347.64 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:40/50 Train_Loss:134.39 Test_Loss:157.43 Train_Acc 75.00 % Test_Acc 77.78 %
# Epoch:41/50 Train_Loss:89.75 Test_Loss:830.53 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:42/50 Train_Loss:87.43 Test_Loss:695.24 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:160.47 Test_Loss:748.58 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:44/50 Train_Loss:89.74 Test_Loss:162.81 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:45/50 Train_Loss:149.00 Test_Loss:645.82 Train_Acc 61.11 % Test_Acc 33.33 %
# Epoch:46/50 Train_Loss:238.46 Test_Loss:330.06 Train_Acc 52.78 % Test_Acc 66.67 %
# Epoch:47/50 Train_Loss:339.14 Test_Loss:20.26 Train_Acc 61.11 % Test_Acc 88.89 %
# Epoch:48/50 Train_Loss:283.84 Test_Loss:140.57 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:49/50 Train_Loss:199.96 Test_Loss:186.92 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:50/50 Train_Loss:152.74 Test_Loss:301.74 Train_Acc 72.22 % Test_Acc 44.44 %
# Fold Number5
# Epoch:1/50 Train_Loss:16690.99 Test_Loss:66125.10 Train_Acc 44.44 % Test_Acc 44.44 %
# Epoch:2/50 Train_Loss:7196.22 Test_Loss:6168.71 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:3/50 Train_Loss:2198.41 Test_Loss:1106.64 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:4/50 Train_Loss:3053.24 Test_Loss:5167.00 Train_Acc 55.56 % Test_Acc 33.33 %
# Epoch:5/50 Train_Loss:2433.88 Test_Loss:8113.60 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:1794.14 Test_Loss:4593.50 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:7/50 Train_Loss:783.89 Test_Loss:1466.27 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:8/50 Train_Loss:1622.37 Test_Loss:2478.31 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:9/50 Train_Loss:1701.24 Test_Loss:5096.05 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:10/50 Train_Loss:1551.72 Test_Loss:5679.40 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:11/50 Train_Loss:1489.31 Test_Loss:5604.54 Train_Acc 58.33 % Test_Acc 33.33 %
# Epoch:12/50 Train_Loss:1685.37 Test_Loss:4069.17 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:13/50 Train_Loss:694.00 Test_Loss:3606.67 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:14/50 Train_Loss:422.96 Test_Loss:813.03 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:15/50 Train_Loss:738.70 Test_Loss:1507.68 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:16/50 Train_Loss:647.77 Test_Loss:2400.10 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:17/50 Train_Loss:647.93 Test_Loss:1912.03 Train_Acc 58.33 % Test_Acc 33.33 %
# Epoch:18/50 Train_Loss:523.15 Test_Loss:934.52 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:19/50 Train_Loss:724.48 Test_Loss:2008.63 Train_Acc 63.89 % Test_Acc 22.22 %
# Epoch:20/50 Train_Loss:496.50 Test_Loss:502.02 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:21/50 Train_Loss:518.32 Test_Loss:1040.32 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:22/50 Train_Loss:478.65 Test_Loss:4161.36 Train_Acc 61.11 % Test_Acc 33.33 %
# Epoch:23/50 Train_Loss:745.17 Test_Loss:2140.14 Train_Acc 69.44 % Test_Acc 22.22 %
# Epoch:24/50 Train_Loss:238.81 Test_Loss:1440.54 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:25/50 Train_Loss:372.65 Test_Loss:2711.10 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:26/50 Train_Loss:794.92 Test_Loss:1109.85 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:493.64 Test_Loss:1597.42 Train_Acc 61.11 % Test_Acc 33.33 %
# Epoch:28/50 Train_Loss:286.41 Test_Loss:1302.36 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:29/50 Train_Loss:296.90 Test_Loss:1889.10 Train_Acc 66.67 % Test_Acc 22.22 %
# Epoch:30/50 Train_Loss:263.58 Test_Loss:2437.79 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:31/50 Train_Loss:198.49 Test_Loss:1264.04 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:32/50 Train_Loss:213.85 Test_Loss:1045.85 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:33/50 Train_Loss:108.91 Test_Loss:1622.21 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:34/50 Train_Loss:443.01 Test_Loss:639.43 Train_Acc 44.44 % Test_Acc 44.44 %
# Epoch:35/50 Train_Loss:578.79 Test_Loss:1436.08 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:36/50 Train_Loss:238.58 Test_Loss:2355.15 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:37/50 Train_Loss:308.50 Test_Loss:1896.92 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:38/50 Train_Loss:257.68 Test_Loss:1252.63 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:39/50 Train_Loss:634.59 Test_Loss:1554.08 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:40/50 Train_Loss:692.11 Test_Loss:2960.02 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:41/50 Train_Loss:631.91 Test_Loss:1702.58 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:42/50 Train_Loss:369.92 Test_Loss:1538.13 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:43/50 Train_Loss:305.01 Test_Loss:2070.93 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:44/50 Train_Loss:346.70 Test_Loss:2464.55 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:45/50 Train_Loss:619.60 Test_Loss:723.45 Train_Acc 63.89 % Test_Acc 77.78 %
# Epoch:46/50 Train_Loss:519.41 Test_Loss:263.12 Train_Acc 58.33 % Test_Acc 44.44 %
# Epoch:47/50 Train_Loss:307.32 Test_Loss:762.03 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:48/50 Train_Loss:393.41 Test_Loss:557.94 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:381.30 Test_Loss:940.51 Train_Acc 55.56 % Test_Acc 33.33 %
# Epoch:50/50 Train_Loss:290.11 Test_Loss:297.20 Train_Acc 69.44 % Test_Acc 55.56 %

# %%
testl_f,tl_f,testa_f,ta_f=[],[],[],[]


k=5
for f in range(1,k+1):

    tl_f.append(np.mean(foldperf['fold{}'.format(f)]['train_loss']))
    testl_f.append(np.mean(foldperf['fold{}'.format(f)]['test_loss']))

    ta_f.append(np.mean(foldperf['fold{}'.format(f)]['train_acc']))
    testa_f.append(np.mean(foldperf['fold{}'.format(f)]['test_acc']))

print('{} fold cross validation'.format(k))
print("Avg Training Loss: {:.3f} \t Avg Test Loss: {:.3f} \t Avg Training Acc: {:.2f} \t Avg Test Acc: {:.2f}".format(np.mean(tl_f),np.mean(testl_f),np.mean(ta_f),np.mean(testa_f)))
# Out:
# 5 fold cross validation
# Avg Training Loss: 1202.765 	 Avg Test Loss: 2982.400 	 Avg Training Acc: 65.37 	 Avg Test Acc: 53.16

# %%
diz_ep = {'train_loss_ep':[],'test_loss_ep':[],'train_acc_ep':[],'test_acc_ep':[]}

for i in range(num_epochs):
    diz_ep['train_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_loss'][i] for f in range(k)]))
    diz_ep['test_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_loss'][i] for f in range(k)]))
    diz_ep['train_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_acc'][i] for f in range(k)]))
    diz_ep['test_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_acc'][i] for f in range(k)]))

# %%
# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(diz_ep['train_loss_ep'], label='Train')
plt.semilogy(diz_ep['test_loss_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.grid()
plt.legend()
plt.title('3D_CNN loss')
plt.show()

# Plot accuracies
plt.figure(figsize=(10,8))
plt.semilogy(diz_ep['train_acc_ep'], label='Train')
plt.semilogy(diz_ep['test_acc_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.grid()
plt.legend()
plt.title('3D_CNN accuracy')
plt.show()

# %%
# Model name = GAttCNN_StK7F


b_s=3

device = torch.device('cuda:0')


error = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

dataset=CEUS_Dataset(df, train=True)

y=CEUS_Dataset(df, train = False)


num_epochs=50

k=7
splits=StratifiedKFold(n_splits=k,shuffle=False,random_state=None)


foldperf={}



for fold, (train_x,test_x) in enumerate(splits.split(dataset, y)):

    print('Fold Number= {}'.format(fold + 1))

    train_sampler = (train_x)
    test_sampler = (test_x)
    trainLoader = DataLoader(dataset, batch_size=b_s,  sampler=train_sampler)
    testLoader = DataLoader(dataset, batch_size=b_s, sampler=test_sampler)
    
    model = Unet_grid_attention()
    
    
    optimizer = optim.Adam(model.parameters(), lr=0.0003)
    

    l_a = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

    for epoch in range(num_epochs):
        
        train_loss, train_correct=train_epoch(model,trainLoader,error,optimizer)
        test_loss, test_correct,e=test_epoch(model,testLoader,error)

        train_loss = train_loss / len(trainLoader.sampler)
        train_acc = train_correct / len(trainLoader.sampler) * 100
        test_loss = test_loss / len(testLoader.sampler)
        test_acc = test_correct / len(testLoader.sampler) * 100

        print("Epoch:{}/{} Train_Loss:{:.2f} Test_Loss:{:.2f} Train_Acc {:.2f} % Test_Acc {:.2f} %".format(epoch + 1, 
                                                                                                       num_epochs, 
                                                                                                       train_loss, 
                                                                                                       test_loss, 
                                                                                                       train_acc, 
                                                                                                       test_acc))
        

        l_a['train_loss'].append(train_loss)
        l_a['test_loss'].append(test_loss)
        l_a['train_acc'].append(train_acc)
        l_a['test_acc'].append(test_acc)
        
    plt.figure(figsize=(5,5))    
    test_loss, test_correct,e=test_epoch(model,testLoader,error)
    df_cm = pd.DataFrame(e, index=["Benign", "Malignant"], columns=["Benign", "Malignant"]).astype(int)
    heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
        

        
        
    foldperf['fold{}'.format(fold+1)] = l_a
# Out:
# Fold Number= 1
# Epoch:1/50 Train_Loss:4904.05 Test_Loss:6551.65 Train_Acc 63.16 % Test_Acc 42.86 %
# Epoch:2/50 Train_Loss:2787.58 Test_Loss:8438.81 Train_Acc 55.26 % Test_Acc 42.86 %
# Epoch:3/50 Train_Loss:623.63 Test_Loss:14739.39 Train_Acc 76.32 % Test_Acc 42.86 %
# Epoch:4/50 Train_Loss:514.20 Test_Loss:3782.91 Train_Acc 76.32 % Test_Acc 42.86 %
# Epoch:5/50 Train_Loss:869.89 Test_Loss:2252.25 Train_Acc 71.05 % Test_Acc 42.86 %
# Epoch:6/50 Train_Loss:1442.60 Test_Loss:11977.26 Train_Acc 60.53 % Test_Acc 57.14 %
# Epoch:7/50 Train_Loss:1245.50 Test_Loss:3228.03 Train_Acc 68.42 % Test_Acc 71.43 %
# Epoch:8/50 Train_Loss:876.61 Test_Loss:1212.40 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:9/50 Train_Loss:702.51 Test_Loss:2939.83 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:10/50 Train_Loss:236.01 Test_Loss:4551.77 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:11/50 Train_Loss:325.33 Test_Loss:3053.48 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:12/50 Train_Loss:616.34 Test_Loss:2433.37 Train_Acc 73.68 % Test_Acc 71.43 %
# Epoch:13/50 Train_Loss:468.36 Test_Loss:2313.46 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:14/50 Train_Loss:378.53 Test_Loss:3665.62 Train_Acc 89.47 % Test_Acc 57.14 %
# Epoch:15/50 Train_Loss:441.44 Test_Loss:1873.87 Train_Acc 73.68 % Test_Acc 71.43 %
# Epoch:16/50 Train_Loss:255.70 Test_Loss:2339.91 Train_Acc 89.47 % Test_Acc 42.86 %
# Epoch:17/50 Train_Loss:400.44 Test_Loss:2443.75 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:18/50 Train_Loss:440.80 Test_Loss:2597.04 Train_Acc 73.68 % Test_Acc 42.86 %
# Epoch:19/50 Train_Loss:289.83 Test_Loss:1741.58 Train_Acc 68.42 % Test_Acc 57.14 %
# Epoch:20/50 Train_Loss:207.42 Test_Loss:2319.52 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:21/50 Train_Loss:380.81 Test_Loss:2538.65 Train_Acc 76.32 % Test_Acc 71.43 %
# Epoch:22/50 Train_Loss:398.03 Test_Loss:1782.94 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:23/50 Train_Loss:158.49 Test_Loss:1525.89 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:24/50 Train_Loss:204.85 Test_Loss:3861.94 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:25/50 Train_Loss:309.55 Test_Loss:2650.03 Train_Acc 73.68 % Test_Acc 71.43 %
# Epoch:26/50 Train_Loss:296.23 Test_Loss:4905.85 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:27/50 Train_Loss:194.03 Test_Loss:4103.40 Train_Acc 84.21 % Test_Acc 42.86 %
# Epoch:28/50 Train_Loss:122.01 Test_Loss:2752.97 Train_Acc 84.21 % Test_Acc 42.86 %
# Epoch:29/50 Train_Loss:167.93 Test_Loss:3295.03 Train_Acc 84.21 % Test_Acc 42.86 %
# Epoch:30/50 Train_Loss:151.79 Test_Loss:2392.79 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:31/50 Train_Loss:125.84 Test_Loss:2469.61 Train_Acc 81.58 % Test_Acc 42.86 %
# Epoch:32/50 Train_Loss:107.83 Test_Loss:2678.53 Train_Acc 86.84 % Test_Acc 42.86 %
# Epoch:33/50 Train_Loss:104.70 Test_Loss:2404.81 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:34/50 Train_Loss:123.15 Test_Loss:2222.79 Train_Acc 89.47 % Test_Acc 42.86 %
# Epoch:35/50 Train_Loss:97.66 Test_Loss:1890.91 Train_Acc 92.11 % Test_Acc 42.86 %
# Epoch:36/50 Train_Loss:92.96 Test_Loss:2282.45 Train_Acc 84.21 % Test_Acc 42.86 %
# Epoch:37/50 Train_Loss:132.73 Test_Loss:2051.78 Train_Acc 81.58 % Test_Acc 42.86 %
# Epoch:38/50 Train_Loss:128.58 Test_Loss:1696.79 Train_Acc 92.11 % Test_Acc 57.14 %
# Epoch:39/50 Train_Loss:94.30 Test_Loss:1218.64 Train_Acc 92.11 % Test_Acc 57.14 %
# Epoch:40/50 Train_Loss:100.60 Test_Loss:2465.36 Train_Acc 86.84 % Test_Acc 28.57 %
# Epoch:41/50 Train_Loss:150.64 Test_Loss:1853.25 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:42/50 Train_Loss:158.66 Test_Loss:1090.06 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:43/50 Train_Loss:86.23 Test_Loss:1209.35 Train_Acc 94.74 % Test_Acc 42.86 %
# Epoch:44/50 Train_Loss:93.77 Test_Loss:1587.53 Train_Acc 92.11 % Test_Acc 71.43 %
# Epoch:45/50 Train_Loss:85.11 Test_Loss:1201.22 Train_Acc 89.47 % Test_Acc 57.14 %
# Epoch:46/50 Train_Loss:113.46 Test_Loss:1160.60 Train_Acc 89.47 % Test_Acc 28.57 %
# Epoch:47/50 Train_Loss:105.67 Test_Loss:1410.68 Train_Acc 86.84 % Test_Acc 71.43 %
# Epoch:48/50 Train_Loss:84.76 Test_Loss:1296.81 Train_Acc 86.84 % Test_Acc 42.86 %
# Epoch:49/50 Train_Loss:83.25 Test_Loss:1215.37 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:50/50 Train_Loss:96.52 Test_Loss:1127.99 Train_Acc 92.11 % Test_Acc 57.14 %
# Fold Number= 2
# Epoch:1/50 Train_Loss:8112.98 Test_Loss:13141.89 Train_Acc 47.37 % Test_Acc 57.14 %
# Epoch:2/50 Train_Loss:5814.64 Test_Loss:4255.74 Train_Acc 50.00 % Test_Acc 57.14 %
# Epoch:3/50 Train_Loss:1565.59 Test_Loss:2483.55 Train_Acc 68.42 % Test_Acc 57.14 %
# Epoch:4/50 Train_Loss:1490.78 Test_Loss:4102.69 Train_Acc 65.79 % Test_Acc 42.86 %
# Epoch:5/50 Train_Loss:955.41 Test_Loss:6676.64 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:6/50 Train_Loss:2529.41 Test_Loss:15075.66 Train_Acc 55.26 % Test_Acc 42.86 %
# Epoch:7/50 Train_Loss:2512.79 Test_Loss:1616.99 Train_Acc 63.16 % Test_Acc 71.43 %
# Epoch:8/50 Train_Loss:2414.66 Test_Loss:2418.12 Train_Acc 63.16 % Test_Acc 28.57 %
# Epoch:9/50 Train_Loss:916.06 Test_Loss:4410.25 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:10/50 Train_Loss:1711.61 Test_Loss:734.89 Train_Acc 57.89 % Test_Acc 57.14 %
# Epoch:11/50 Train_Loss:986.69 Test_Loss:363.21 Train_Acc 65.79 % Test_Acc 71.43 %
# Epoch:12/50 Train_Loss:685.98 Test_Loss:1245.79 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:13/50 Train_Loss:276.63 Test_Loss:4012.39 Train_Acc 84.21 % Test_Acc 28.57 %
# Epoch:14/50 Train_Loss:474.71 Test_Loss:1065.35 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:15/50 Train_Loss:684.24 Test_Loss:1192.82 Train_Acc 76.32 % Test_Acc 42.86 %
# Epoch:16/50 Train_Loss:341.39 Test_Loss:791.64 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:17/50 Train_Loss:245.87 Test_Loss:795.21 Train_Acc 89.47 % Test_Acc 71.43 %
# Epoch:18/50 Train_Loss:214.98 Test_Loss:2930.91 Train_Acc 78.95 % Test_Acc 28.57 %
# Epoch:19/50 Train_Loss:300.71 Test_Loss:1031.45 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:20/50 Train_Loss:670.75 Test_Loss:6376.51 Train_Acc 71.05 % Test_Acc 42.86 %
# Epoch:21/50 Train_Loss:772.85 Test_Loss:1552.78 Train_Acc 76.32 % Test_Acc 71.43 %
# Epoch:22/50 Train_Loss:532.30 Test_Loss:5216.16 Train_Acc 73.68 % Test_Acc 42.86 %
# Epoch:23/50 Train_Loss:602.72 Test_Loss:1343.15 Train_Acc 68.42 % Test_Acc 57.14 %
# Epoch:24/50 Train_Loss:534.69 Test_Loss:1969.23 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:25/50 Train_Loss:822.80 Test_Loss:943.51 Train_Acc 65.79 % Test_Acc 57.14 %
# Epoch:26/50 Train_Loss:908.39 Test_Loss:4647.16 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:27/50 Train_Loss:1168.05 Test_Loss:1346.54 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:28/50 Train_Loss:486.60 Test_Loss:3580.96 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:29/50 Train_Loss:1041.65 Test_Loss:1383.23 Train_Acc 68.42 % Test_Acc 42.86 %
# Epoch:30/50 Train_Loss:1140.33 Test_Loss:4088.16 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:31/50 Train_Loss:773.67 Test_Loss:1764.59 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:32/50 Train_Loss:549.48 Test_Loss:2390.14 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:33/50 Train_Loss:324.05 Test_Loss:665.84 Train_Acc 86.84 % Test_Acc 85.71 %
# Epoch:34/50 Train_Loss:521.44 Test_Loss:822.85 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:35/50 Train_Loss:240.36 Test_Loss:2120.95 Train_Acc 92.11 % Test_Acc 57.14 %
# Epoch:36/50 Train_Loss:213.52 Test_Loss:709.97 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:37/50 Train_Loss:227.06 Test_Loss:1078.07 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:38/50 Train_Loss:245.79 Test_Loss:1427.23 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:39/50 Train_Loss:284.74 Test_Loss:798.81 Train_Acc 81.58 % Test_Acc 42.86 %
# Epoch:40/50 Train_Loss:468.82 Test_Loss:1616.83 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:41/50 Train_Loss:300.77 Test_Loss:2237.87 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:42/50 Train_Loss:230.31 Test_Loss:1473.16 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:43/50 Train_Loss:777.76 Test_Loss:958.22 Train_Acc 71.05 % Test_Acc 57.14 %
# Epoch:44/50 Train_Loss:267.78 Test_Loss:1824.73 Train_Acc 78.95 % Test_Acc 71.43 %
# Epoch:45/50 Train_Loss:228.01 Test_Loss:823.87 Train_Acc 81.58 % Test_Acc 71.43 %
# Epoch:46/50 Train_Loss:290.26 Test_Loss:1363.15 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:47/50 Train_Loss:251.51 Test_Loss:1299.84 Train_Acc 86.84 % Test_Acc 42.86 %
# Epoch:48/50 Train_Loss:243.61 Test_Loss:1173.73 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:49/50 Train_Loss:192.58 Test_Loss:489.75 Train_Acc 84.21 % Test_Acc 71.43 %
# Epoch:50/50 Train_Loss:413.19 Test_Loss:1108.75 Train_Acc 78.95 % Test_Acc 42.86 %
# Fold Number= 3
# Epoch:1/50 Train_Loss:8092.94 Test_Loss:3415.31 Train_Acc 42.11 % Test_Acc 57.14 %
# Epoch:2/50 Train_Loss:2356.48 Test_Loss:5375.62 Train_Acc 63.16 % Test_Acc 57.14 %
# Epoch:3/50 Train_Loss:2007.77 Test_Loss:2974.17 Train_Acc 63.16 % Test_Acc 42.86 %
# Epoch:4/50 Train_Loss:679.93 Test_Loss:2231.82 Train_Acc 86.84 % Test_Acc 42.86 %
# Epoch:5/50 Train_Loss:1069.12 Test_Loss:7883.61 Train_Acc 68.42 % Test_Acc 42.86 %
# Epoch:6/50 Train_Loss:761.32 Test_Loss:4346.56 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:7/50 Train_Loss:1475.51 Test_Loss:9728.08 Train_Acc 63.16 % Test_Acc 42.86 %
# Epoch:8/50 Train_Loss:1173.30 Test_Loss:4633.57 Train_Acc 68.42 % Test_Acc 57.14 %
# Epoch:9/50 Train_Loss:551.87 Test_Loss:3801.66 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:10/50 Train_Loss:622.57 Test_Loss:9098.03 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:11/50 Train_Loss:670.36 Test_Loss:6169.75 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:12/50 Train_Loss:697.55 Test_Loss:2330.07 Train_Acc 73.68 % Test_Acc 42.86 %
# Epoch:13/50 Train_Loss:765.22 Test_Loss:3774.81 Train_Acc 76.32 % Test_Acc 42.86 %
# Epoch:14/50 Train_Loss:428.79 Test_Loss:6042.89 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:15/50 Train_Loss:643.58 Test_Loss:9896.56 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:16/50 Train_Loss:644.72 Test_Loss:2506.80 Train_Acc 68.42 % Test_Acc 28.57 %
# Epoch:17/50 Train_Loss:843.26 Test_Loss:8432.11 Train_Acc 71.05 % Test_Acc 57.14 %
# Epoch:18/50 Train_Loss:643.75 Test_Loss:7611.51 Train_Acc 73.68 % Test_Acc 57.14 %
# Epoch:19/50 Train_Loss:961.44 Test_Loss:6954.86 Train_Acc 71.05 % Test_Acc 57.14 %
# Epoch:20/50 Train_Loss:352.70 Test_Loss:33290.52 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:21/50 Train_Loss:1332.52 Test_Loss:13750.24 Train_Acc 71.05 % Test_Acc 57.14 %
# Epoch:22/50 Train_Loss:729.83 Test_Loss:7532.41 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:23/50 Train_Loss:530.84 Test_Loss:3933.91 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:24/50 Train_Loss:585.81 Test_Loss:7489.09 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:25/50 Train_Loss:324.44 Test_Loss:6415.84 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:26/50 Train_Loss:326.91 Test_Loss:2904.79 Train_Acc 89.47 % Test_Acc 57.14 %
# Epoch:27/50 Train_Loss:308.96 Test_Loss:6578.84 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:28/50 Train_Loss:219.37 Test_Loss:4462.61 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:29/50 Train_Loss:357.04 Test_Loss:3773.98 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:30/50 Train_Loss:435.74 Test_Loss:7412.23 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:31/50 Train_Loss:361.42 Test_Loss:3821.52 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:32/50 Train_Loss:413.83 Test_Loss:3763.91 Train_Acc 81.58 % Test_Acc 42.86 %
# Epoch:33/50 Train_Loss:363.20 Test_Loss:6021.52 Train_Acc 78.95 % Test_Acc 57.14 %
# Epoch:34/50 Train_Loss:242.33 Test_Loss:3910.54 Train_Acc 89.47 % Test_Acc 57.14 %
# Epoch:35/50 Train_Loss:223.06 Test_Loss:3753.29 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:36/50 Train_Loss:191.04 Test_Loss:5265.41 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:37/50 Train_Loss:388.11 Test_Loss:6678.83 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:38/50 Train_Loss:288.07 Test_Loss:4644.37 Train_Acc 71.05 % Test_Acc 57.14 %
# Epoch:39/50 Train_Loss:420.81 Test_Loss:3909.18 Train_Acc 84.21 % Test_Acc 42.86 %
# Epoch:40/50 Train_Loss:267.95 Test_Loss:7093.18 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:41/50 Train_Loss:208.85 Test_Loss:4884.35 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:42/50 Train_Loss:239.87 Test_Loss:4361.95 Train_Acc 86.84 % Test_Acc 57.14 %
# Epoch:43/50 Train_Loss:231.29 Test_Loss:4944.36 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:44/50 Train_Loss:239.89 Test_Loss:4068.03 Train_Acc 84.21 % Test_Acc 57.14 %
# Epoch:45/50 Train_Loss:389.82 Test_Loss:3972.72 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:46/50 Train_Loss:414.16 Test_Loss:7178.25 Train_Acc 76.32 % Test_Acc 57.14 %
# Epoch:47/50 Train_Loss:429.05 Test_Loss:2730.54 Train_Acc 78.95 % Test_Acc 42.86 %
# Epoch:48/50 Train_Loss:418.90 Test_Loss:4900.25 Train_Acc 81.58 % Test_Acc 57.14 %
# Epoch:49/50 Train_Loss:130.95 Test_Loss:2746.35 Train_Acc 86.84 % Test_Acc 42.86 %
# Epoch:50/50 Train_Loss:118.14 Test_Loss:4525.38 Train_Acc 78.95 % Test_Acc 57.14 %
# Fold Number= 4
# Epoch:1/50 Train_Loss:14350.49 Test_Loss:20389.93 Train_Acc 43.59 % Test_Acc 50.00 %
# Epoch:2/50 Train_Loss:4730.98 Test_Loss:3504.42 Train_Acc 61.54 % Test_Acc 50.00 %
# Epoch:3/50 Train_Loss:2745.58 Test_Loss:883.29 Train_Acc 58.97 % Test_Acc 66.67 %
# Epoch:4/50 Train_Loss:646.00 Test_Loss:1082.95 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:5/50 Train_Loss:1673.55 Test_Loss:4465.35 Train_Acc 64.10 % Test_Acc 50.00 %
# Epoch:6/50 Train_Loss:1749.85 Test_Loss:7578.34 Train_Acc 74.36 % Test_Acc 50.00 %
# Epoch:7/50 Train_Loss:1165.52 Test_Loss:2306.64 Train_Acc 66.67 % Test_Acc 50.00 %
# Epoch:8/50 Train_Loss:1373.00 Test_Loss:11359.16 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:9/50 Train_Loss:1167.16 Test_Loss:1938.57 Train_Acc 66.67 % Test_Acc 50.00 %
# Epoch:10/50 Train_Loss:776.64 Test_Loss:5564.20 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:11/50 Train_Loss:666.61 Test_Loss:1020.20 Train_Acc 76.92 % Test_Acc 33.33 %
# Epoch:12/50 Train_Loss:684.32 Test_Loss:288.95 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:13/50 Train_Loss:375.33 Test_Loss:4216.95 Train_Acc 84.62 % Test_Acc 66.67 %
# Epoch:14/50 Train_Loss:289.22 Test_Loss:1165.75 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:15/50 Train_Loss:302.91 Test_Loss:560.53 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:16/50 Train_Loss:166.65 Test_Loss:2613.77 Train_Acc 82.05 % Test_Acc 50.00 %
# Epoch:17/50 Train_Loss:279.99 Test_Loss:1968.44 Train_Acc 82.05 % Test_Acc 50.00 %
# Epoch:18/50 Train_Loss:455.84 Test_Loss:1069.04 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:19/50 Train_Loss:227.97 Test_Loss:1283.42 Train_Acc 82.05 % Test_Acc 66.67 %
# Epoch:20/50 Train_Loss:412.47 Test_Loss:2798.90 Train_Acc 87.18 % Test_Acc 50.00 %
# Epoch:21/50 Train_Loss:320.81 Test_Loss:131.38 Train_Acc 87.18 % Test_Acc 66.67 %
# Epoch:22/50 Train_Loss:411.52 Test_Loss:2522.66 Train_Acc 84.62 % Test_Acc 50.00 %
# Epoch:23/50 Train_Loss:143.77 Test_Loss:1083.24 Train_Acc 84.62 % Test_Acc 66.67 %
# Epoch:24/50 Train_Loss:464.59 Test_Loss:2572.45 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:25/50 Train_Loss:363.37 Test_Loss:1384.28 Train_Acc 84.62 % Test_Acc 66.67 %
# Epoch:26/50 Train_Loss:366.80 Test_Loss:420.53 Train_Acc 87.18 % Test_Acc 66.67 %
# Epoch:27/50 Train_Loss:248.96 Test_Loss:3619.52 Train_Acc 92.31 % Test_Acc 50.00 %
# Epoch:28/50 Train_Loss:373.94 Test_Loss:1079.60 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:29/50 Train_Loss:337.79 Test_Loss:6508.96 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:30/50 Train_Loss:552.41 Test_Loss:1116.18 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:335.35 Test_Loss:1177.73 Train_Acc 82.05 % Test_Acc 50.00 %
# Epoch:32/50 Train_Loss:177.23 Test_Loss:2390.05 Train_Acc 89.74 % Test_Acc 66.67 %
# Epoch:33/50 Train_Loss:239.41 Test_Loss:950.05 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:34/50 Train_Loss:243.27 Test_Loss:3223.14 Train_Acc 82.05 % Test_Acc 50.00 %
# Epoch:35/50 Train_Loss:390.04 Test_Loss:625.23 Train_Acc 84.62 % Test_Acc 50.00 %
# Epoch:36/50 Train_Loss:205.31 Test_Loss:268.83 Train_Acc 82.05 % Test_Acc 66.67 %
# Epoch:37/50 Train_Loss:458.02 Test_Loss:3917.36 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:38/50 Train_Loss:361.77 Test_Loss:755.25 Train_Acc 74.36 % Test_Acc 83.33 %
# Epoch:39/50 Train_Loss:253.49 Test_Loss:1721.19 Train_Acc 84.62 % Test_Acc 66.67 %
# Epoch:40/50 Train_Loss:103.53 Test_Loss:3953.85 Train_Acc 89.74 % Test_Acc 50.00 %
# Epoch:41/50 Train_Loss:369.19 Test_Loss:573.79 Train_Acc 87.18 % Test_Acc 66.67 %
# Epoch:42/50 Train_Loss:175.71 Test_Loss:3520.95 Train_Acc 87.18 % Test_Acc 50.00 %
# Epoch:43/50 Train_Loss:225.16 Test_Loss:345.89 Train_Acc 82.05 % Test_Acc 83.33 %
# Epoch:44/50 Train_Loss:192.57 Test_Loss:733.18 Train_Acc 82.05 % Test_Acc 66.67 %
# Epoch:45/50 Train_Loss:187.21 Test_Loss:268.51 Train_Acc 84.62 % Test_Acc 83.33 %
# Epoch:46/50 Train_Loss:113.94 Test_Loss:2203.86 Train_Acc 84.62 % Test_Acc 50.00 %
# Epoch:47/50 Train_Loss:157.55 Test_Loss:374.28 Train_Acc 89.74 % Test_Acc 83.33 %
# Epoch:48/50 Train_Loss:100.34 Test_Loss:706.65 Train_Acc 89.74 % Test_Acc 66.67 %
# Epoch:49/50 Train_Loss:180.93 Test_Loss:1338.57 Train_Acc 89.74 % Test_Acc 66.67 %
# Epoch:50/50 Train_Loss:142.73 Test_Loss:380.55 Train_Acc 89.74 % Test_Acc 66.67 %
# Fold Number= 5
# Epoch:1/50 Train_Loss:7597.96 Test_Loss:10287.54 Train_Acc 56.41 % Test_Acc 66.67 %
# Epoch:2/50 Train_Loss:8517.09 Test_Loss:2198.36 Train_Acc 53.85 % Test_Acc 83.33 %
# Epoch:3/50 Train_Loss:3655.32 Test_Loss:3725.78 Train_Acc 53.85 % Test_Acc 66.67 %
# Epoch:4/50 Train_Loss:1485.08 Test_Loss:431.50 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:5/50 Train_Loss:2091.55 Test_Loss:1652.37 Train_Acc 51.28 % Test_Acc 66.67 %
# Epoch:6/50 Train_Loss:1011.50 Test_Loss:1633.39 Train_Acc 69.23 % Test_Acc 50.00 %
# Epoch:7/50 Train_Loss:1178.96 Test_Loss:1358.17 Train_Acc 64.10 % Test_Acc 66.67 %
# Epoch:8/50 Train_Loss:976.50 Test_Loss:652.72 Train_Acc 74.36 % Test_Acc 83.33 %
# Epoch:9/50 Train_Loss:802.29 Test_Loss:502.16 Train_Acc 69.23 % Test_Acc 50.00 %
# Epoch:10/50 Train_Loss:1479.91 Test_Loss:409.12 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:11/50 Train_Loss:563.69 Test_Loss:311.90 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:12/50 Train_Loss:771.80 Test_Loss:933.85 Train_Acc 56.41 % Test_Acc 50.00 %
# Epoch:13/50 Train_Loss:1046.24 Test_Loss:1305.92 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:14/50 Train_Loss:700.07 Test_Loss:322.38 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:15/50 Train_Loss:362.52 Test_Loss:1674.94 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:16/50 Train_Loss:871.26 Test_Loss:181.55 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:17/50 Train_Loss:624.83 Test_Loss:23.41 Train_Acc 66.67 % Test_Acc 83.33 %
# Epoch:18/50 Train_Loss:644.91 Test_Loss:589.56 Train_Acc 61.54 % Test_Acc 83.33 %
# Epoch:19/50 Train_Loss:689.24 Test_Loss:1605.68 Train_Acc 66.67 % Test_Acc 83.33 %
# Epoch:20/50 Train_Loss:814.65 Test_Loss:1651.69 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:21/50 Train_Loss:363.51 Test_Loss:99.62 Train_Acc 69.23 % Test_Acc 83.33 %
# Epoch:22/50 Train_Loss:270.17 Test_Loss:1589.12 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:23/50 Train_Loss:612.55 Test_Loss:1020.33 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:24/50 Train_Loss:829.08 Test_Loss:588.11 Train_Acc 69.23 % Test_Acc 83.33 %
# Epoch:25/50 Train_Loss:544.34 Test_Loss:244.62 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:26/50 Train_Loss:575.52 Test_Loss:952.48 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:27/50 Train_Loss:310.84 Test_Loss:446.89 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:350.31 Test_Loss:1179.29 Train_Acc 84.62 % Test_Acc 50.00 %
# Epoch:29/50 Train_Loss:347.94 Test_Loss:613.76 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:30/50 Train_Loss:398.43 Test_Loss:154.77 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:286.27 Test_Loss:477.46 Train_Acc 82.05 % Test_Acc 66.67 %
# Epoch:32/50 Train_Loss:545.84 Test_Loss:1915.84 Train_Acc 61.54 % Test_Acc 33.33 %
# Epoch:33/50 Train_Loss:259.65 Test_Loss:272.94 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:34/50 Train_Loss:534.77 Test_Loss:758.79 Train_Acc 64.10 % Test_Acc 83.33 %
# Epoch:35/50 Train_Loss:536.08 Test_Loss:468.58 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:36/50 Train_Loss:161.61 Test_Loss:659.01 Train_Acc 89.74 % Test_Acc 83.33 %
# Epoch:37/50 Train_Loss:364.34 Test_Loss:48.92 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:38/50 Train_Loss:169.14 Test_Loss:338.00 Train_Acc 82.05 % Test_Acc 83.33 %
# Epoch:39/50 Train_Loss:252.02 Test_Loss:108.90 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:40/50 Train_Loss:241.81 Test_Loss:314.05 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:41/50 Train_Loss:235.83 Test_Loss:620.11 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:42/50 Train_Loss:267.01 Test_Loss:351.47 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:334.32 Test_Loss:463.42 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:44/50 Train_Loss:320.19 Test_Loss:424.13 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:45/50 Train_Loss:157.56 Test_Loss:298.98 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:257.00 Test_Loss:717.86 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:47/50 Train_Loss:183.33 Test_Loss:11.31 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:48/50 Train_Loss:394.06 Test_Loss:200.59 Train_Acc 71.79 % Test_Acc 83.33 %
# Epoch:49/50 Train_Loss:379.53 Test_Loss:552.30 Train_Acc 82.05 % Test_Acc 83.33 %
# Epoch:50/50 Train_Loss:526.62 Test_Loss:21.96 Train_Acc 69.23 % Test_Acc 83.33 %
# Fold Number= 6
# Epoch:1/50 Train_Loss:6368.66 Test_Loss:7813.39 Train_Acc 53.85 % Test_Acc 33.33 %
# Epoch:2/50 Train_Loss:4574.34 Test_Loss:7426.55 Train_Acc 48.72 % Test_Acc 33.33 %
# Epoch:3/50 Train_Loss:712.81 Test_Loss:1422.45 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:4/50 Train_Loss:1296.15 Test_Loss:2317.09 Train_Acc 56.41 % Test_Acc 50.00 %
# Epoch:5/50 Train_Loss:585.15 Test_Loss:1908.64 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:6/50 Train_Loss:812.46 Test_Loss:1326.23 Train_Acc 69.23 % Test_Acc 50.00 %
# Epoch:7/50 Train_Loss:605.41 Test_Loss:3343.44 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:8/50 Train_Loss:1111.81 Test_Loss:3233.29 Train_Acc 58.97 % Test_Acc 50.00 %
# Epoch:9/50 Train_Loss:239.52 Test_Loss:1057.79 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:10/50 Train_Loss:273.69 Test_Loss:3035.10 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:11/50 Train_Loss:624.54 Test_Loss:1013.73 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:12/50 Train_Loss:545.23 Test_Loss:173.09 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:13/50 Train_Loss:332.33 Test_Loss:1846.95 Train_Acc 79.49 % Test_Acc 33.33 %
# Epoch:14/50 Train_Loss:260.37 Test_Loss:128.55 Train_Acc 82.05 % Test_Acc 83.33 %
# Epoch:15/50 Train_Loss:268.44 Test_Loss:56.01 Train_Acc 84.62 % Test_Acc 66.67 %
# Epoch:16/50 Train_Loss:314.82 Test_Loss:1343.48 Train_Acc 76.92 % Test_Acc 33.33 %
# Epoch:17/50 Train_Loss:203.12 Test_Loss:76.24 Train_Acc 87.18 % Test_Acc 83.33 %
# Epoch:18/50 Train_Loss:302.25 Test_Loss:238.75 Train_Acc 71.79 % Test_Acc 83.33 %
# Epoch:19/50 Train_Loss:283.54 Test_Loss:1201.68 Train_Acc 84.62 % Test_Acc 33.33 %
# Epoch:20/50 Train_Loss:234.90 Test_Loss:62.02 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:21/50 Train_Loss:196.03 Test_Loss:249.57 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:22/50 Train_Loss:455.30 Test_Loss:3827.93 Train_Acc 74.36 % Test_Acc 33.33 %
# Epoch:23/50 Train_Loss:1263.29 Test_Loss:67.46 Train_Acc 51.28 % Test_Acc 66.67 %
# Epoch:24/50 Train_Loss:576.12 Test_Loss:796.53 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:25/50 Train_Loss:707.04 Test_Loss:3008.59 Train_Acc 82.05 % Test_Acc 33.33 %
# Epoch:26/50 Train_Loss:343.55 Test_Loss:363.15 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:27/50 Train_Loss:313.87 Test_Loss:1274.27 Train_Acc 87.18 % Test_Acc 33.33 %
# Epoch:28/50 Train_Loss:179.57 Test_Loss:505.12 Train_Acc 79.49 % Test_Acc 33.33 %
# Epoch:29/50 Train_Loss:270.57 Test_Loss:442.31 Train_Acc 64.10 % Test_Acc 66.67 %
# Epoch:30/50 Train_Loss:140.53 Test_Loss:1272.28 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:267.95 Test_Loss:531.30 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:32/50 Train_Loss:301.02 Test_Loss:241.17 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:33/50 Train_Loss:129.10 Test_Loss:1736.05 Train_Acc 82.05 % Test_Acc 33.33 %
# Epoch:34/50 Train_Loss:174.29 Test_Loss:446.09 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:35/50 Train_Loss:122.06 Test_Loss:711.33 Train_Acc 79.49 % Test_Acc 33.33 %
# Epoch:36/50 Train_Loss:199.51 Test_Loss:1879.33 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:37/50 Train_Loss:397.34 Test_Loss:980.07 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:38/50 Train_Loss:298.46 Test_Loss:716.12 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:39/50 Train_Loss:248.91 Test_Loss:236.27 Train_Acc 69.23 % Test_Acc 83.33 %
# Epoch:40/50 Train_Loss:171.31 Test_Loss:239.56 Train_Acc 74.36 % Test_Acc 83.33 %
# Epoch:41/50 Train_Loss:185.11 Test_Loss:344.82 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:42/50 Train_Loss:224.86 Test_Loss:423.92 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:186.89 Test_Loss:696.30 Train_Acc 79.49 % Test_Acc 33.33 %
# Epoch:44/50 Train_Loss:274.45 Test_Loss:203.46 Train_Acc 76.92 % Test_Acc 83.33 %
# Epoch:45/50 Train_Loss:132.90 Test_Loss:241.49 Train_Acc 82.05 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:172.89 Test_Loss:168.95 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:47/50 Train_Loss:153.52 Test_Loss:1419.61 Train_Acc 79.49 % Test_Acc 16.67 %
# Epoch:48/50 Train_Loss:291.05 Test_Loss:231.80 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:49/50 Train_Loss:142.84 Test_Loss:339.26 Train_Acc 79.49 % Test_Acc 33.33 %
# Epoch:50/50 Train_Loss:234.77 Test_Loss:516.37 Train_Acc 71.79 % Test_Acc 66.67 %
# Fold Number= 7
# Epoch:1/50 Train_Loss:10306.90 Test_Loss:28717.29 Train_Acc 51.28 % Test_Acc 33.33 %
# Epoch:2/50 Train_Loss:5177.83 Test_Loss:11062.13 Train_Acc 61.54 % Test_Acc 66.67 %
# Epoch:3/50 Train_Loss:2690.26 Test_Loss:14572.89 Train_Acc 71.79 % Test_Acc 16.67 %
# Epoch:4/50 Train_Loss:2676.05 Test_Loss:5579.69 Train_Acc 58.97 % Test_Acc 66.67 %
# Epoch:5/50 Train_Loss:1301.03 Test_Loss:9637.72 Train_Acc 74.36 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:886.55 Test_Loss:2515.39 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:7/50 Train_Loss:1071.13 Test_Loss:18785.80 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:8/50 Train_Loss:1567.40 Test_Loss:9593.69 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:9/50 Train_Loss:792.21 Test_Loss:1027.58 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:10/50 Train_Loss:1573.83 Test_Loss:16070.19 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:11/50 Train_Loss:1848.66 Test_Loss:13925.28 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:12/50 Train_Loss:910.04 Test_Loss:5015.43 Train_Acc 64.10 % Test_Acc 66.67 %
# Epoch:13/50 Train_Loss:1704.81 Test_Loss:10613.38 Train_Acc 64.10 % Test_Acc 50.00 %
# Epoch:14/50 Train_Loss:1484.82 Test_Loss:4546.80 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:15/50 Train_Loss:444.17 Test_Loss:8296.33 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:16/50 Train_Loss:686.30 Test_Loss:8331.29 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:17/50 Train_Loss:1296.26 Test_Loss:8877.75 Train_Acc 69.23 % Test_Acc 33.33 %
# Epoch:18/50 Train_Loss:951.62 Test_Loss:9761.39 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:19/50 Train_Loss:616.35 Test_Loss:5573.43 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:20/50 Train_Loss:585.58 Test_Loss:5451.77 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:21/50 Train_Loss:428.43 Test_Loss:3580.18 Train_Acc 74.36 % Test_Acc 50.00 %
# Epoch:22/50 Train_Loss:492.48 Test_Loss:3423.33 Train_Acc 74.36 % Test_Acc 66.67 %
# Epoch:23/50 Train_Loss:663.34 Test_Loss:4383.37 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:24/50 Train_Loss:254.40 Test_Loss:4584.76 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:25/50 Train_Loss:299.74 Test_Loss:6609.36 Train_Acc 76.92 % Test_Acc 33.33 %
# Epoch:26/50 Train_Loss:747.86 Test_Loss:6561.52 Train_Acc 74.36 % Test_Acc 50.00 %
# Epoch:27/50 Train_Loss:511.38 Test_Loss:3452.69 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:414.00 Test_Loss:4311.65 Train_Acc 74.36 % Test_Acc 50.00 %
# Epoch:29/50 Train_Loss:324.20 Test_Loss:4542.77 Train_Acc 76.92 % Test_Acc 33.33 %
# Epoch:30/50 Train_Loss:461.76 Test_Loss:3744.67 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:439.23 Test_Loss:5773.72 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:32/50 Train_Loss:297.94 Test_Loss:4496.22 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:33/50 Train_Loss:370.46 Test_Loss:5457.41 Train_Acc 76.92 % Test_Acc 66.67 %
# Epoch:34/50 Train_Loss:935.85 Test_Loss:13975.90 Train_Acc 69.23 % Test_Acc 33.33 %
# Epoch:35/50 Train_Loss:1215.73 Test_Loss:13272.68 Train_Acc 53.85 % Test_Acc 66.67 %
# Epoch:36/50 Train_Loss:579.98 Test_Loss:5082.32 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:37/50 Train_Loss:441.90 Test_Loss:5463.56 Train_Acc 71.79 % Test_Acc 66.67 %
# Epoch:38/50 Train_Loss:675.10 Test_Loss:2836.20 Train_Acc 71.79 % Test_Acc 50.00 %
# Epoch:39/50 Train_Loss:268.21 Test_Loss:4405.02 Train_Acc 82.05 % Test_Acc 33.33 %
# Epoch:40/50 Train_Loss:210.62 Test_Loss:4562.99 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:41/50 Train_Loss:394.30 Test_Loss:3650.38 Train_Acc 79.49 % Test_Acc 50.00 %
# Epoch:42/50 Train_Loss:373.08 Test_Loss:5222.80 Train_Acc 79.49 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:372.75 Test_Loss:3375.57 Train_Acc 76.92 % Test_Acc 33.33 %
# Epoch:44/50 Train_Loss:147.52 Test_Loss:3670.91 Train_Acc 74.36 % Test_Acc 33.33 %
# Epoch:45/50 Train_Loss:218.49 Test_Loss:4510.52 Train_Acc 69.23 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:331.67 Test_Loss:2883.32 Train_Acc 74.36 % Test_Acc 50.00 %
# Epoch:47/50 Train_Loss:362.59 Test_Loss:3503.23 Train_Acc 76.92 % Test_Acc 50.00 %
# Epoch:48/50 Train_Loss:268.42 Test_Loss:3884.43 Train_Acc 71.79 % Test_Acc 33.33 %
# Epoch:49/50 Train_Loss:201.66 Test_Loss:3162.58 Train_Acc 82.05 % Test_Acc 50.00 %
# Epoch:50/50 Train_Loss:212.88 Test_Loss:3314.21 Train_Acc 76.92 % Test_Acc 50.00 %

# %%
testl_f,tl_f,testa_f,ta_f=[],[],[],[]
k=7
for f in range(1,k+1):

    tl_f.append(np.mean(foldperf['fold{}'.format(f)]['train_loss']))
    testl_f.append(np.mean(foldperf['fold{}'.format(f)]['test_loss']))

    ta_f.append(np.mean(foldperf['fold{}'.format(f)]['train_acc']))
    testa_f.append(np.mean(foldperf['fold{}'.format(f)]['test_acc']))

print('{} fold cross validation'.format(k))

print("Avg Training Loss: {:.3f} \t Avg Test Loss: {:.3f} \t Avg Training Acc: {:.2f} \t Avg Test Acc: {:.2f}".format(np.mean(tl_f),np.mean(testl_f),np.mean(ta_f),np.mean(testa_f)))
# Out:
# 7 fold cross validation
# Avg Training Loss: 790.390 	 Avg Test Loss: 3302.136 	 Avg Training Acc: 75.95 	 Avg Test Acc: 56.50

# %%
diz_ep = {'train_loss_ep':[],'test_loss_ep':[],'train_acc_ep':[],'test_acc_ep':[]}

for i in range(num_epochs):
    diz_ep['train_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_loss'][i] for f in range(k)]))
    diz_ep['test_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_loss'][i] for f in range(k)]))
    diz_ep['train_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_acc'][i] for f in range(k)]))
    diz_ep['test_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_acc'][i] for f in range(k)]))

# %%
# Plot losses
plt.figure(figsize=(10,10))
plt.semilogy(diz_ep['train_loss_ep'], label='Train')
plt.semilogy(diz_ep['test_loss_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.grid()
plt.legend()
plt.title('3D_CNN loss with StratifiedKFold 7KFold')
plt.show()

# Plot accuracies
plt.figure(figsize=(10,10))
plt.semilogy(diz_ep['train_acc_ep'], label='Train')
plt.semilogy(diz_ep['test_acc_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.grid()
plt.legend()
plt.title('3D_CNN accuracy with StratifiedKFold 7KFold')
plt.show()

# %%
# Model name = GAttCNN_StK5F


b_s=3

device = torch.device('cuda:0')


error = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

dataset=CEUS_Dataset(df, train=True)

y=CEUS_Dataset(df, train = False)


num_epochs=50

k=5
splits=StratifiedKFold(n_splits=k,shuffle=False,random_state=None)


foldperf={}



for fold, (train_x,test_x) in enumerate(splits.split(dataset, y)):

    print('Fold Number= {}'.format(fold + 1))

    train_sampler = (train_x)
    test_sampler = (test_x)
    trainLoader = DataLoader(dataset, batch_size=b_s,  sampler=train_sampler)
    testLoader = DataLoader(dataset, batch_size=b_s, sampler=test_sampler)
    
    model = Unet_grid_attention()
    
    
    optimizer = optim.Adam(model.parameters(), lr=0.0003)
    

    l_a = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

    for epoch in range(num_epochs):
        
        train_loss, train_correct=train_epoch(model,trainLoader,error,optimizer)
        test_loss, test_correct,e=test_epoch(model,testLoader,error)

        train_loss = train_loss / len(trainLoader.sampler)
        train_acc = train_correct / len(trainLoader.sampler) * 100
        test_loss = test_loss / len(testLoader.sampler)
        test_acc = test_correct / len(testLoader.sampler) * 100

        print("Epoch:{}/{} Train_Loss:{:.2f} Test_Loss:{:.2f} Train_Acc {:.2f} % Test_Acc {:.2f} %".format(epoch + 1, 
                                                                                                       num_epochs, 
                                                                                                       train_loss, 
                                                                                                       test_loss, 
                                                                                                       train_acc, 
                                                                                                       test_acc))
        

        l_a['train_loss'].append(train_loss)
        l_a['test_loss'].append(test_loss)
        l_a['train_acc'].append(train_acc)
        l_a['test_acc'].append(test_acc)
        
    plt.figure(figsize=(5,5))    
    test_loss, test_correct,e=test_epoch(model,testLoader,error)
    df_cm = pd.DataFrame(e, index=["Benign", "Malignant"], columns=["Benign", "Malignant"]).astype(int)
    heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
        

        
        
    foldperf['fold{}'.format(fold+1)] = l_a
# Out:
# Fold Number= 1
# Epoch:1/50 Train_Loss:4394.78 Test_Loss:4798.33 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:2/50 Train_Loss:5742.73 Test_Loss:11710.90 Train_Acc 58.33 % Test_Acc 33.33 %
# Epoch:3/50 Train_Loss:2026.62 Test_Loss:6053.55 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:4/50 Train_Loss:3677.88 Test_Loss:5827.67 Train_Acc 50.00 % Test_Acc 33.33 %
# Epoch:5/50 Train_Loss:789.99 Test_Loss:8073.22 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:6/50 Train_Loss:1695.72 Test_Loss:2926.52 Train_Acc 50.00 % Test_Acc 22.22 %
# Epoch:7/50 Train_Loss:564.71 Test_Loss:1263.42 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:8/50 Train_Loss:752.26 Test_Loss:2282.33 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:9/50 Train_Loss:329.53 Test_Loss:2508.98 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:10/50 Train_Loss:800.47 Test_Loss:7722.07 Train_Acc 61.11 % Test_Acc 44.44 %
# Epoch:11/50 Train_Loss:1013.21 Test_Loss:2616.09 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:12/50 Train_Loss:782.77 Test_Loss:3884.16 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:13/50 Train_Loss:851.35 Test_Loss:1986.78 Train_Acc 55.56 % Test_Acc 33.33 %
# Epoch:14/50 Train_Loss:220.72 Test_Loss:2348.48 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:15/50 Train_Loss:371.18 Test_Loss:1757.30 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:16/50 Train_Loss:309.91 Test_Loss:2154.89 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:17/50 Train_Loss:365.62 Test_Loss:1992.36 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:18/50 Train_Loss:443.16 Test_Loss:1564.55 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:19/50 Train_Loss:465.62 Test_Loss:3295.48 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:20/50 Train_Loss:446.28 Test_Loss:1911.06 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:21/50 Train_Loss:259.75 Test_Loss:2092.20 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:22/50 Train_Loss:347.00 Test_Loss:2288.04 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:23/50 Train_Loss:472.11 Test_Loss:281.84 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:24/50 Train_Loss:337.61 Test_Loss:539.41 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:25/50 Train_Loss:168.85 Test_Loss:192.78 Train_Acc 77.78 % Test_Acc 77.78 %
# Epoch:26/50 Train_Loss:155.70 Test_Loss:1355.16 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:27/50 Train_Loss:229.30 Test_Loss:471.74 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:168.30 Test_Loss:816.76 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:29/50 Train_Loss:172.49 Test_Loss:1989.51 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:30/50 Train_Loss:318.89 Test_Loss:775.84 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:31/50 Train_Loss:157.73 Test_Loss:1574.39 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:32/50 Train_Loss:115.43 Test_Loss:630.57 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:33/50 Train_Loss:130.88 Test_Loss:2019.39 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:34/50 Train_Loss:364.44 Test_Loss:513.25 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:35/50 Train_Loss:177.32 Test_Loss:1043.26 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:36/50 Train_Loss:152.39 Test_Loss:2155.09 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:37/50 Train_Loss:245.68 Test_Loss:694.79 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:38/50 Train_Loss:206.67 Test_Loss:3535.72 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:39/50 Train_Loss:497.62 Test_Loss:1398.69 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:40/50 Train_Loss:461.12 Test_Loss:5234.13 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:41/50 Train_Loss:369.61 Test_Loss:3144.95 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:42/50 Train_Loss:276.63 Test_Loss:2044.59 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:43/50 Train_Loss:96.65 Test_Loss:3181.10 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:44/50 Train_Loss:214.70 Test_Loss:2383.63 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:45/50 Train_Loss:83.96 Test_Loss:3461.35 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:46/50 Train_Loss:185.22 Test_Loss:2034.20 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:47/50 Train_Loss:220.40 Test_Loss:3035.16 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:48/50 Train_Loss:228.17 Test_Loss:1765.41 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:152.03 Test_Loss:1278.68 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:50/50 Train_Loss:104.35 Test_Loss:878.82 Train_Acc 72.22 % Test_Acc 44.44 %
# Fold Number= 2
# Epoch:1/50 Train_Loss:10055.27 Test_Loss:24733.28 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:2/50 Train_Loss:3976.19 Test_Loss:11232.32 Train_Acc 52.78 % Test_Acc 55.56 %
# Epoch:3/50 Train_Loss:1774.87 Test_Loss:21036.45 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:4/50 Train_Loss:3044.99 Test_Loss:15370.11 Train_Acc 66.67 % Test_Acc 44.44 %
# Epoch:5/50 Train_Loss:2029.15 Test_Loss:17390.10 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:6/50 Train_Loss:2034.49 Test_Loss:3307.38 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:7/50 Train_Loss:1870.76 Test_Loss:8009.18 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:8/50 Train_Loss:493.70 Test_Loss:8546.58 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:9/50 Train_Loss:939.92 Test_Loss:2565.33 Train_Acc 69.44 % Test_Acc 22.22 %
# Epoch:10/50 Train_Loss:708.69 Test_Loss:7244.12 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:11/50 Train_Loss:571.77 Test_Loss:4001.78 Train_Acc 86.11 % Test_Acc 22.22 %
# Epoch:12/50 Train_Loss:260.46 Test_Loss:5687.03 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:13/50 Train_Loss:876.80 Test_Loss:7634.64 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:14/50 Train_Loss:595.78 Test_Loss:4569.87 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:15/50 Train_Loss:325.74 Test_Loss:3135.69 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:16/50 Train_Loss:233.53 Test_Loss:3403.66 Train_Acc 83.33 % Test_Acc 33.33 %
# Epoch:17/50 Train_Loss:410.52 Test_Loss:4834.56 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:18/50 Train_Loss:387.90 Test_Loss:4554.47 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:19/50 Train_Loss:542.20 Test_Loss:8859.77 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:20/50 Train_Loss:1125.97 Test_Loss:7145.32 Train_Acc 58.33 % Test_Acc 55.56 %
# Epoch:21/50 Train_Loss:787.71 Test_Loss:5993.79 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:22/50 Train_Loss:358.51 Test_Loss:4799.47 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:23/50 Train_Loss:653.54 Test_Loss:5512.78 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:24/50 Train_Loss:568.20 Test_Loss:3517.77 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:25/50 Train_Loss:188.42 Test_Loss:1821.04 Train_Acc 88.89 % Test_Acc 44.44 %
# Epoch:26/50 Train_Loss:215.97 Test_Loss:3783.57 Train_Acc 91.67 % Test_Acc 33.33 %
# Epoch:27/50 Train_Loss:202.00 Test_Loss:2544.36 Train_Acc 88.89 % Test_Acc 33.33 %
# Epoch:28/50 Train_Loss:130.64 Test_Loss:1976.39 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:29/50 Train_Loss:157.81 Test_Loss:3426.47 Train_Acc 83.33 % Test_Acc 22.22 %
# Epoch:30/50 Train_Loss:313.54 Test_Loss:1934.30 Train_Acc 69.44 % Test_Acc 33.33 %
# Epoch:31/50 Train_Loss:162.44 Test_Loss:2489.87 Train_Acc 80.56 % Test_Acc 22.22 %
# Epoch:32/50 Train_Loss:275.12 Test_Loss:3286.09 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:33/50 Train_Loss:153.06 Test_Loss:2661.87 Train_Acc 86.11 % Test_Acc 22.22 %
# Epoch:34/50 Train_Loss:72.56 Test_Loss:2587.24 Train_Acc 83.33 % Test_Acc 22.22 %
# Epoch:35/50 Train_Loss:196.86 Test_Loss:3060.38 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:36/50 Train_Loss:162.99 Test_Loss:2789.23 Train_Acc 88.89 % Test_Acc 44.44 %
# Epoch:37/50 Train_Loss:182.85 Test_Loss:2804.00 Train_Acc 91.67 % Test_Acc 44.44 %
# Epoch:38/50 Train_Loss:251.04 Test_Loss:2461.85 Train_Acc 83.33 % Test_Acc 22.22 %
# Epoch:39/50 Train_Loss:152.76 Test_Loss:3170.31 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:40/50 Train_Loss:256.12 Test_Loss:3239.95 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:41/50 Train_Loss:279.29 Test_Loss:3707.57 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:42/50 Train_Loss:164.16 Test_Loss:1810.77 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:43/50 Train_Loss:188.65 Test_Loss:1805.00 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:44/50 Train_Loss:110.99 Test_Loss:2333.02 Train_Acc 83.33 % Test_Acc 33.33 %
# Epoch:45/50 Train_Loss:225.45 Test_Loss:2549.94 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:46/50 Train_Loss:243.89 Test_Loss:1491.24 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:47/50 Train_Loss:146.88 Test_Loss:2507.20 Train_Acc 88.89 % Test_Acc 33.33 %
# Epoch:48/50 Train_Loss:166.33 Test_Loss:1646.45 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:278.89 Test_Loss:2091.26 Train_Acc 86.11 % Test_Acc 11.11 %
# Epoch:50/50 Train_Loss:265.57 Test_Loss:1496.18 Train_Acc 77.78 % Test_Acc 33.33 %
# Fold Number= 3
# Epoch:1/50 Train_Loss:10044.84 Test_Loss:5379.69 Train_Acc 33.33 % Test_Acc 44.44 %
# Epoch:2/50 Train_Loss:1446.08 Test_Loss:3838.10 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:3/50 Train_Loss:2607.02 Test_Loss:5278.76 Train_Acc 47.22 % Test_Acc 44.44 %
# Epoch:4/50 Train_Loss:1899.10 Test_Loss:2206.47 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:5/50 Train_Loss:381.28 Test_Loss:1372.75 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:6/50 Train_Loss:482.33 Test_Loss:2992.98 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:7/50 Train_Loss:433.87 Test_Loss:2186.65 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:8/50 Train_Loss:1550.72 Test_Loss:497.68 Train_Acc 52.78 % Test_Acc 66.67 %
# Epoch:9/50 Train_Loss:675.43 Test_Loss:6954.05 Train_Acc 80.56 % Test_Acc 33.33 %
# Epoch:10/50 Train_Loss:1345.03 Test_Loss:7256.02 Train_Acc 61.11 % Test_Acc 55.56 %
# Epoch:11/50 Train_Loss:893.07 Test_Loss:1226.62 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:12/50 Train_Loss:235.26 Test_Loss:772.25 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:13/50 Train_Loss:286.33 Test_Loss:3083.96 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:14/50 Train_Loss:413.41 Test_Loss:4239.73 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:15/50 Train_Loss:767.87 Test_Loss:6163.58 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:16/50 Train_Loss:927.09 Test_Loss:1363.31 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:17/50 Train_Loss:387.28 Test_Loss:1558.30 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:18/50 Train_Loss:212.43 Test_Loss:1187.44 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:19/50 Train_Loss:172.98 Test_Loss:2049.10 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:20/50 Train_Loss:728.35 Test_Loss:784.05 Train_Acc 80.56 % Test_Acc 66.67 %
# Epoch:21/50 Train_Loss:363.11 Test_Loss:1195.43 Train_Acc 88.89 % Test_Acc 55.56 %
# Epoch:22/50 Train_Loss:365.49 Test_Loss:1798.70 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:23/50 Train_Loss:227.87 Test_Loss:892.04 Train_Acc 88.89 % Test_Acc 55.56 %
# Epoch:24/50 Train_Loss:161.53 Test_Loss:1013.99 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:25/50 Train_Loss:197.50 Test_Loss:2264.17 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:26/50 Train_Loss:322.44 Test_Loss:2099.29 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:335.16 Test_Loss:897.34 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:28/50 Train_Loss:394.35 Test_Loss:489.55 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:29/50 Train_Loss:144.65 Test_Loss:1022.18 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:30/50 Train_Loss:195.21 Test_Loss:1043.06 Train_Acc 80.56 % Test_Acc 77.78 %
# Epoch:31/50 Train_Loss:241.01 Test_Loss:673.01 Train_Acc 88.89 % Test_Acc 55.56 %
# Epoch:32/50 Train_Loss:354.24 Test_Loss:1603.42 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:33/50 Train_Loss:266.29 Test_Loss:1177.07 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:34/50 Train_Loss:195.36 Test_Loss:840.18 Train_Acc 88.89 % Test_Acc 44.44 %
# Epoch:35/50 Train_Loss:127.36 Test_Loss:1090.53 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:36/50 Train_Loss:126.89 Test_Loss:1388.48 Train_Acc 91.67 % Test_Acc 44.44 %
# Epoch:37/50 Train_Loss:148.29 Test_Loss:734.94 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:38/50 Train_Loss:175.24 Test_Loss:951.66 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:39/50 Train_Loss:120.67 Test_Loss:1038.69 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:40/50 Train_Loss:130.24 Test_Loss:807.90 Train_Acc 86.11 % Test_Acc 55.56 %
# Epoch:41/50 Train_Loss:196.71 Test_Loss:154.04 Train_Acc 86.11 % Test_Acc 77.78 %
# Epoch:42/50 Train_Loss:277.66 Test_Loss:567.34 Train_Acc 86.11 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:187.57 Test_Loss:1059.17 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:44/50 Train_Loss:164.26 Test_Loss:1030.40 Train_Acc 86.11 % Test_Acc 33.33 %
# Epoch:45/50 Train_Loss:185.36 Test_Loss:1783.84 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:193.11 Test_Loss:1099.94 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:47/50 Train_Loss:341.43 Test_Loss:1143.77 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:48/50 Train_Loss:301.24 Test_Loss:544.88 Train_Acc 86.11 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:187.23 Test_Loss:1442.73 Train_Acc 75.00 % Test_Acc 22.22 %
# Epoch:50/50 Train_Loss:169.35 Test_Loss:2200.48 Train_Acc 86.11 % Test_Acc 66.67 %
# Fold Number= 4
# Epoch:1/50 Train_Loss:6251.94 Test_Loss:5619.61 Train_Acc 50.00 % Test_Acc 66.67 %
# Epoch:2/50 Train_Loss:3270.38 Test_Loss:4232.28 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:3/50 Train_Loss:3402.66 Test_Loss:2165.23 Train_Acc 47.22 % Test_Acc 55.56 %
# Epoch:4/50 Train_Loss:1226.88 Test_Loss:2211.17 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:5/50 Train_Loss:984.49 Test_Loss:2937.35 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:556.20 Test_Loss:1411.79 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:7/50 Train_Loss:431.61 Test_Loss:1846.38 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:8/50 Train_Loss:814.87 Test_Loss:1248.95 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:9/50 Train_Loss:1087.87 Test_Loss:2611.25 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:10/50 Train_Loss:1073.70 Test_Loss:5381.81 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:11/50 Train_Loss:1300.49 Test_Loss:3105.57 Train_Acc 63.89 % Test_Acc 66.67 %
# Epoch:12/50 Train_Loss:508.67 Test_Loss:4266.72 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:13/50 Train_Loss:450.22 Test_Loss:1698.71 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:14/50 Train_Loss:679.45 Test_Loss:1411.55 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:15/50 Train_Loss:672.10 Test_Loss:920.88 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:16/50 Train_Loss:471.42 Test_Loss:1308.63 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:17/50 Train_Loss:178.30 Test_Loss:1642.17 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:18/50 Train_Loss:715.88 Test_Loss:4567.43 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:19/50 Train_Loss:837.60 Test_Loss:1211.81 Train_Acc 55.56 % Test_Acc 44.44 %
# Epoch:20/50 Train_Loss:421.78 Test_Loss:1665.64 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:21/50 Train_Loss:514.71 Test_Loss:4252.88 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:22/50 Train_Loss:857.00 Test_Loss:2061.68 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:23/50 Train_Loss:223.32 Test_Loss:1142.02 Train_Acc 77.78 % Test_Acc 33.33 %
# Epoch:24/50 Train_Loss:320.91 Test_Loss:1095.54 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:25/50 Train_Loss:432.61 Test_Loss:3492.84 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:26/50 Train_Loss:837.47 Test_Loss:2986.00 Train_Acc 52.78 % Test_Acc 66.67 %
# Epoch:27/50 Train_Loss:671.93 Test_Loss:4066.98 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:28/50 Train_Loss:664.13 Test_Loss:1986.81 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:29/50 Train_Loss:454.36 Test_Loss:1139.00 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:30/50 Train_Loss:361.36 Test_Loss:1550.12 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:31/50 Train_Loss:235.46 Test_Loss:1511.60 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:32/50 Train_Loss:223.31 Test_Loss:1454.34 Train_Acc 83.33 % Test_Acc 33.33 %
# Epoch:33/50 Train_Loss:232.39 Test_Loss:1574.06 Train_Acc 77.78 % Test_Acc 44.44 %
# Epoch:34/50 Train_Loss:424.19 Test_Loss:858.67 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:35/50 Train_Loss:515.66 Test_Loss:1367.05 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:36/50 Train_Loss:395.38 Test_Loss:1106.53 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:37/50 Train_Loss:226.51 Test_Loss:1708.25 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:38/50 Train_Loss:212.64 Test_Loss:625.80 Train_Acc 69.44 % Test_Acc 44.44 %
# Epoch:39/50 Train_Loss:166.78 Test_Loss:485.34 Train_Acc 75.00 % Test_Acc 33.33 %
# Epoch:40/50 Train_Loss:148.69 Test_Loss:890.96 Train_Acc 80.56 % Test_Acc 66.67 %
# Epoch:41/50 Train_Loss:403.11 Test_Loss:1107.36 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:42/50 Train_Loss:444.30 Test_Loss:2141.26 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:43/50 Train_Loss:443.02 Test_Loss:1386.54 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:44/50 Train_Loss:432.51 Test_Loss:1637.54 Train_Acc 80.56 % Test_Acc 44.44 %
# Epoch:45/50 Train_Loss:240.40 Test_Loss:892.87 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:46/50 Train_Loss:341.34 Test_Loss:1095.04 Train_Acc 72.22 % Test_Acc 44.44 %
# Epoch:47/50 Train_Loss:147.85 Test_Loss:1000.17 Train_Acc 83.33 % Test_Acc 44.44 %
# Epoch:48/50 Train_Loss:291.48 Test_Loss:1496.73 Train_Acc 75.00 % Test_Acc 44.44 %
# Epoch:49/50 Train_Loss:176.53 Test_Loss:1097.54 Train_Acc 63.89 % Test_Acc 44.44 %
# Epoch:50/50 Train_Loss:442.50 Test_Loss:2671.25 Train_Acc 72.22 % Test_Acc 33.33 %
# Fold Number= 5
# Epoch:1/50 Train_Loss:11923.38 Test_Loss:27624.29 Train_Acc 58.33 % Test_Acc 33.33 %
# Epoch:2/50 Train_Loss:4742.98 Test_Loss:4884.38 Train_Acc 58.33 % Test_Acc 66.67 %
# Epoch:3/50 Train_Loss:2464.09 Test_Loss:7649.73 Train_Acc 69.44 % Test_Acc 33.33 %
# Epoch:4/50 Train_Loss:1606.18 Test_Loss:3178.83 Train_Acc 61.11 % Test_Acc 66.67 %
# Epoch:5/50 Train_Loss:746.42 Test_Loss:929.21 Train_Acc 69.44 % Test_Acc 33.33 %
# Epoch:6/50 Train_Loss:1716.09 Test_Loss:16444.30 Train_Acc 52.78 % Test_Acc 66.67 %
# Epoch:7/50 Train_Loss:2468.74 Test_Loss:15958.33 Train_Acc 58.33 % Test_Acc 33.33 %
# Epoch:8/50 Train_Loss:1835.07 Test_Loss:3048.49 Train_Acc 69.44 % Test_Acc 66.67 %
# Epoch:9/50 Train_Loss:1614.82 Test_Loss:5832.32 Train_Acc 69.44 % Test_Acc 77.78 %
# Epoch:10/50 Train_Loss:1964.13 Test_Loss:4845.81 Train_Acc 72.22 % Test_Acc 33.33 %
# Epoch:11/50 Train_Loss:1252.34 Test_Loss:11863.20 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:12/50 Train_Loss:780.50 Test_Loss:5608.57 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:13/50 Train_Loss:482.84 Test_Loss:4921.38 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:14/50 Train_Loss:763.36 Test_Loss:3651.93 Train_Acc 69.44 % Test_Acc 77.78 %
# Epoch:15/50 Train_Loss:500.31 Test_Loss:2626.33 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:16/50 Train_Loss:1142.70 Test_Loss:2274.56 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:17/50 Train_Loss:348.75 Test_Loss:1508.03 Train_Acc 75.00 % Test_Acc 66.67 %
# Epoch:18/50 Train_Loss:297.01 Test_Loss:2639.29 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:19/50 Train_Loss:419.45 Test_Loss:3681.48 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:20/50 Train_Loss:704.44 Test_Loss:2706.22 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:21/50 Train_Loss:536.46 Test_Loss:2688.13 Train_Acc 72.22 % Test_Acc 66.67 %
# Epoch:22/50 Train_Loss:736.25 Test_Loss:3765.90 Train_Acc 80.56 % Test_Acc 77.78 %
# Epoch:23/50 Train_Loss:473.73 Test_Loss:1648.11 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:24/50 Train_Loss:414.26 Test_Loss:3500.92 Train_Acc 77.78 % Test_Acc 66.67 %
# Epoch:25/50 Train_Loss:444.36 Test_Loss:2220.29 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:26/50 Train_Loss:193.57 Test_Loss:3536.93 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:27/50 Train_Loss:277.03 Test_Loss:1490.73 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:28/50 Train_Loss:484.26 Test_Loss:2314.60 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:29/50 Train_Loss:233.41 Test_Loss:3104.46 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:30/50 Train_Loss:290.88 Test_Loss:937.18 Train_Acc 80.56 % Test_Acc 55.56 %
# Epoch:31/50 Train_Loss:402.65 Test_Loss:3186.47 Train_Acc 72.22 % Test_Acc 77.78 %
# Epoch:32/50 Train_Loss:472.35 Test_Loss:2981.56 Train_Acc 69.44 % Test_Acc 55.56 %
# Epoch:33/50 Train_Loss:214.65 Test_Loss:1374.22 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:34/50 Train_Loss:378.12 Test_Loss:2370.22 Train_Acc 80.56 % Test_Acc 77.78 %
# Epoch:35/50 Train_Loss:386.21 Test_Loss:2752.65 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:36/50 Train_Loss:314.56 Test_Loss:1215.47 Train_Acc 83.33 % Test_Acc 55.56 %
# Epoch:37/50 Train_Loss:283.78 Test_Loss:3865.24 Train_Acc 75.00 % Test_Acc 77.78 %
# Epoch:38/50 Train_Loss:451.74 Test_Loss:1112.06 Train_Acc 66.67 % Test_Acc 55.56 %
# Epoch:39/50 Train_Loss:255.38 Test_Loss:2223.83 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:40/50 Train_Loss:345.96 Test_Loss:2801.86 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:41/50 Train_Loss:337.83 Test_Loss:1786.87 Train_Acc 75.00 % Test_Acc 55.56 %
# Epoch:42/50 Train_Loss:219.75 Test_Loss:1894.67 Train_Acc 83.33 % Test_Acc 66.67 %
# Epoch:43/50 Train_Loss:220.89 Test_Loss:1445.55 Train_Acc 77.78 % Test_Acc 22.22 %
# Epoch:44/50 Train_Loss:238.66 Test_Loss:1610.88 Train_Acc 77.78 % Test_Acc 77.78 %
# Epoch:45/50 Train_Loss:488.47 Test_Loss:1804.28 Train_Acc 80.56 % Test_Acc 66.67 %
# Epoch:46/50 Train_Loss:159.55 Test_Loss:1173.07 Train_Acc 77.78 % Test_Acc 55.56 %
# Epoch:47/50 Train_Loss:234.23 Test_Loss:1436.98 Train_Acc 77.78 % Test_Acc 22.22 %
# Epoch:48/50 Train_Loss:388.59 Test_Loss:4876.59 Train_Acc 63.89 % Test_Acc 55.56 %
# Epoch:49/50 Train_Loss:496.56 Test_Loss:4801.42 Train_Acc 72.22 % Test_Acc 55.56 %
# Epoch:50/50 Train_Loss:331.66 Test_Loss:3721.12 Train_Acc 88.89 % Test_Acc 55.56 %

# %%
testl_f,tl_f,testa_f,ta_f=[],[],[],[]
k=5
for f in range(1,k+1):

    tl_f.append(np.mean(foldperf['fold{}'.format(f)]['train_loss']))
    testl_f.append(np.mean(foldperf['fold{}'.format(f)]['test_loss']))

    ta_f.append(np.mean(foldperf['fold{}'.format(f)]['train_acc']))
    testa_f.append(np.mean(foldperf['fold{}'.format(f)]['test_acc']))

print('{} fold Stratified cross validation'.format(k))

print("Avg Training Loss: {:.3f} \t Avg Test Loss: {:.3f} \t Avg Training Acc: {:.2f} \t Avg Test Acc: {:.2f}".format(np.mean(tl_f),np.mean(testl_f),np.mean(ta_f),np.mean(testa_f)))
# Out:
# 5 fold Stratified cross validation
# Avg Training Loss: 763.483 	 Avg Test Loss: 3157.424 	 Avg Training Acc: 74.57 	 Avg Test Acc: 49.02

# %%
diz_ep = {'train_loss_ep':[],'test_loss_ep':[],'train_acc_ep':[],'test_acc_ep':[]}

for i in range(num_epochs):
    diz_ep['train_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_loss'][i] for f in range(k)]))
    diz_ep['test_loss_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_loss'][i] for f in range(k)]))
    diz_ep['train_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['train_acc'][i] for f in range(k)]))
    diz_ep['test_acc_ep'].append(np.mean([foldperf['fold{}'.format(f+1)]['test_acc'][i] for f in range(k)]))

# %%
# Plot losses
plt.figure(figsize=(10,10))
plt.semilogy(diz_ep['train_loss_ep'], label='Train')
plt.semilogy(diz_ep['test_loss_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.grid()
plt.legend()
plt.title('3D_CNN loss with StratifiedKFold 5KFold')
plt.show()

# Plot accuracies
plt.figure(figsize=(10,10))
plt.semilogy(diz_ep['train_acc_ep'], label='Train')
plt.semilogy(diz_ep['test_acc_ep'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.grid()
plt.legend()
plt.title('3D_CNN accuracy with StratifiedKFold 5KFold')
plt.show()

# %%
# Model name = GAttCNN_n



device = torch.device('cuda:0')

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)


dataset = ConcatDataset([train_dataset, test_dataset])

num_epochs=200
batch_size=3

l_a = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

for epoch in range(num_epochs):
    
    model=model.to(device)
    
    train_loss,train_correct=0.0,0
    model.train()
    for images, labels in train_loader:

        labels=labels.type(torch.LongTensor).to(device)
        images=images.to(device)
        with torch.set_grad_enabled(True):
            optimizer.zero_grad()
            output = model(images)
            loss = loss_fn(output,labels)
            loss.backward()
            optimizer.step()
            
        train_loss += loss.item() * images.size(0)
        scores, predictions = torch.max(output.data, 1)
        train_correct += (predictions == labels).sum().item()
    
    test_loss, test_correct = 0.0, 0
    confusion_matrix = torch.zeros(2, 2)
    
    model.eval() 
    for images, labels in test_loader:
        
        labels=labels.type(torch.LongTensor).to(device)
        images=images.to(device)
        
        with torch.set_grad_enabled(False):
            output = model(images)
            loss=loss_fn(output,labels)

            test_loss+=loss.item()*images.size(0)
        scores, predictions = torch.max(output.data,1)
        test_correct+=(predictions == labels).sum().item()
        for t, p in zip(labels.view(-1), predictions.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

        

    train_loss = train_loss / len(train_loader.sampler)
    train_acc = train_correct / len(train_loader.sampler) * 100
    test_loss = test_loss / len(test_loader.sampler)
    test_acc = test_correct / len(test_loader.sampler) * 100

    print("Epoch:{}/{} Train_Loss:{:.2f} Test_Loss:{:.2f} Train_Acc {:.2f} % Test_Acc {:.2f} %".format(epoch + 1, 
                                                                                                       num_epochs, 
                                                                                                       train_loss, 
                                                                                                       test_loss, 
                                                                                                       train_acc, 
                                                                                                       test_acc))
    
    
    l_a['train_loss'].append(train_loss)
    l_a['test_loss'].append(test_loss)
    l_a['train_acc'].append(train_acc)
    l_a['test_acc'].append(test_acc)
    
    
plt.figure(figsize=(5,5))    
df_cm = pd.DataFrame(confusion_matrix, index=["Benign", "Malignant"], columns=["Benign", "Malignant"]).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Epoch:1/200 Train_Loss:4728.21 Test_Loss:2688.87 Train_Acc 51.52 % Test_Acc 50.00 %
# Epoch:2/200 Train_Loss:3428.94 Test_Loss:7655.55 Train_Acc 51.52 % Test_Acc 66.67 %
# Epoch:3/200 Train_Loss:1464.57 Test_Loss:3083.95 Train_Acc 57.58 % Test_Acc 66.67 %
# Epoch:4/200 Train_Loss:1518.37 Test_Loss:668.72 Train_Acc 75.76 % Test_Acc 75.00 %
# Epoch:5/200 Train_Loss:2810.88 Test_Loss:962.26 Train_Acc 51.52 % Test_Acc 75.00 %
# Epoch:6/200 Train_Loss:1726.48 Test_Loss:2389.16 Train_Acc 60.61 % Test_Acc 50.00 %
# Epoch:7/200 Train_Loss:981.37 Test_Loss:895.49 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:8/200 Train_Loss:759.50 Test_Loss:723.57 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:9/200 Train_Loss:364.23 Test_Loss:995.18 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:10/200 Train_Loss:757.38 Test_Loss:10591.40 Train_Acc 66.67 % Test_Acc 33.33 %
# Epoch:11/200 Train_Loss:1247.84 Test_Loss:5771.94 Train_Acc 60.61 % Test_Acc 66.67 %
# Epoch:12/200 Train_Loss:1918.65 Test_Loss:2509.31 Train_Acc 63.64 % Test_Acc 50.00 %
# Epoch:13/200 Train_Loss:703.82 Test_Loss:3399.00 Train_Acc 66.67 % Test_Acc 50.00 %
# Epoch:14/200 Train_Loss:1362.67 Test_Loss:2839.96 Train_Acc 66.67 % Test_Acc 50.00 %
# Epoch:15/200 Train_Loss:942.24 Test_Loss:905.61 Train_Acc 63.64 % Test_Acc 75.00 %
# Epoch:16/200 Train_Loss:743.08 Test_Loss:3652.71 Train_Acc 63.64 % Test_Acc 58.33 %
# Epoch:17/200 Train_Loss:320.90 Test_Loss:9862.61 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:18/200 Train_Loss:1481.48 Test_Loss:5098.65 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:19/200 Train_Loss:889.89 Test_Loss:1214.81 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:20/200 Train_Loss:784.92 Test_Loss:5212.73 Train_Acc 72.73 % Test_Acc 50.00 %
# Epoch:21/200 Train_Loss:381.29 Test_Loss:1729.40 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:22/200 Train_Loss:607.86 Test_Loss:1639.57 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:23/200 Train_Loss:439.76 Test_Loss:577.06 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:24/200 Train_Loss:487.54 Test_Loss:1937.58 Train_Acc 69.70 % Test_Acc 58.33 %
# Epoch:25/200 Train_Loss:427.24 Test_Loss:545.48 Train_Acc 78.79 % Test_Acc 75.00 %
# Epoch:26/200 Train_Loss:652.35 Test_Loss:942.23 Train_Acc 60.61 % Test_Acc 58.33 %
# Epoch:27/200 Train_Loss:430.83 Test_Loss:982.64 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:28/200 Train_Loss:490.77 Test_Loss:3196.63 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:29/200 Train_Loss:595.04 Test_Loss:1205.91 Train_Acc 69.70 % Test_Acc 75.00 %
# Epoch:30/200 Train_Loss:636.21 Test_Loss:3746.55 Train_Acc 69.70 % Test_Acc 50.00 %
# Epoch:31/200 Train_Loss:279.84 Test_Loss:1390.09 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:32/200 Train_Loss:453.19 Test_Loss:6237.00 Train_Acc 78.79 % Test_Acc 33.33 %
# Epoch:33/200 Train_Loss:792.13 Test_Loss:1009.75 Train_Acc 60.61 % Test_Acc 75.00 %
# Epoch:34/200 Train_Loss:442.89 Test_Loss:3623.73 Train_Acc 78.79 % Test_Acc 50.00 %
# Epoch:35/200 Train_Loss:722.62 Test_Loss:1163.25 Train_Acc 57.58 % Test_Acc 66.67 %
# Epoch:36/200 Train_Loss:426.21 Test_Loss:703.02 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:37/200 Train_Loss:385.35 Test_Loss:1649.92 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:38/200 Train_Loss:348.13 Test_Loss:1734.63 Train_Acc 81.82 % Test_Acc 41.67 %
# Epoch:39/200 Train_Loss:89.96 Test_Loss:893.15 Train_Acc 87.88 % Test_Acc 66.67 %
# Epoch:40/200 Train_Loss:507.97 Test_Loss:448.95 Train_Acc 66.67 % Test_Acc 83.33 %
# Epoch:41/200 Train_Loss:644.52 Test_Loss:2191.83 Train_Acc 60.61 % Test_Acc 50.00 %
# Epoch:42/200 Train_Loss:497.10 Test_Loss:1383.68 Train_Acc 63.64 % Test_Acc 50.00 %
# Epoch:43/200 Train_Loss:294.67 Test_Loss:167.49 Train_Acc 84.85 % Test_Acc 83.33 %
# Epoch:44/200 Train_Loss:183.72 Test_Loss:667.45 Train_Acc 84.85 % Test_Acc 50.00 %
# Epoch:45/200 Train_Loss:217.13 Test_Loss:305.77 Train_Acc 81.82 % Test_Acc 75.00 %
# Epoch:46/200 Train_Loss:292.21 Test_Loss:7702.20 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:47/200 Train_Loss:689.19 Test_Loss:1504.44 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:48/200 Train_Loss:496.32 Test_Loss:1172.23 Train_Acc 72.73 % Test_Acc 66.67 %
# Epoch:49/200 Train_Loss:243.58 Test_Loss:1425.95 Train_Acc 90.91 % Test_Acc 58.33 %
# Epoch:50/200 Train_Loss:352.49 Test_Loss:182.99 Train_Acc 81.82 % Test_Acc 75.00 %
# Epoch:51/200 Train_Loss:270.67 Test_Loss:1995.63 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:52/200 Train_Loss:218.50 Test_Loss:181.10 Train_Acc 81.82 % Test_Acc 66.67 %
# Epoch:53/200 Train_Loss:252.60 Test_Loss:450.54 Train_Acc 72.73 % Test_Acc 50.00 %
# Epoch:54/200 Train_Loss:276.53 Test_Loss:4937.98 Train_Acc 69.70 % Test_Acc 50.00 %
# Epoch:55/200 Train_Loss:669.17 Test_Loss:2092.71 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:56/200 Train_Loss:516.64 Test_Loss:437.92 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:57/200 Train_Loss:471.37 Test_Loss:229.62 Train_Acc 63.64 % Test_Acc 75.00 %
# Epoch:58/200 Train_Loss:256.29 Test_Loss:909.80 Train_Acc 69.70 % Test_Acc 58.33 %
# Epoch:59/200 Train_Loss:444.32 Test_Loss:2982.86 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:60/200 Train_Loss:111.52 Test_Loss:311.16 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:61/200 Train_Loss:240.42 Test_Loss:1705.90 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:62/200 Train_Loss:304.70 Test_Loss:804.72 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:63/200 Train_Loss:61.06 Test_Loss:696.75 Train_Acc 93.94 % Test_Acc 41.67 %
# Epoch:64/200 Train_Loss:120.76 Test_Loss:2553.47 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:65/200 Train_Loss:658.88 Test_Loss:231.98 Train_Acc 69.70 % Test_Acc 75.00 %
# Epoch:66/200 Train_Loss:340.49 Test_Loss:671.43 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:67/200 Train_Loss:319.49 Test_Loss:1721.52 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:68/200 Train_Loss:251.13 Test_Loss:1102.91 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:69/200 Train_Loss:175.25 Test_Loss:1351.81 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:70/200 Train_Loss:315.95 Test_Loss:347.94 Train_Acc 75.76 % Test_Acc 83.33 %
# Epoch:71/200 Train_Loss:191.47 Test_Loss:491.99 Train_Acc 87.88 % Test_Acc 66.67 %
# Epoch:72/200 Train_Loss:278.33 Test_Loss:659.07 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:73/200 Train_Loss:511.52 Test_Loss:411.75 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:74/200 Train_Loss:180.71 Test_Loss:859.27 Train_Acc 75.76 % Test_Acc 58.33 %
# Epoch:75/200 Train_Loss:241.63 Test_Loss:2028.63 Train_Acc 75.76 % Test_Acc 41.67 %
# Epoch:76/200 Train_Loss:126.40 Test_Loss:381.48 Train_Acc 87.88 % Test_Acc 75.00 %
# Epoch:77/200 Train_Loss:381.12 Test_Loss:1898.37 Train_Acc 63.64 % Test_Acc 41.67 %
# Epoch:78/200 Train_Loss:265.09 Test_Loss:724.98 Train_Acc 75.76 % Test_Acc 75.00 %
# Epoch:79/200 Train_Loss:416.71 Test_Loss:660.01 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:80/200 Train_Loss:703.32 Test_Loss:2279.61 Train_Acc 63.64 % Test_Acc 41.67 %
# Epoch:81/200 Train_Loss:700.69 Test_Loss:1855.86 Train_Acc 66.67 % Test_Acc 66.67 %
# Epoch:82/200 Train_Loss:268.86 Test_Loss:640.27 Train_Acc 81.82 % Test_Acc 58.33 %
# Epoch:83/200 Train_Loss:119.05 Test_Loss:1358.48 Train_Acc 81.82 % Test_Acc 58.33 %
# Epoch:84/200 Train_Loss:193.13 Test_Loss:1604.27 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:85/200 Train_Loss:185.30 Test_Loss:1308.86 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:86/200 Train_Loss:279.85 Test_Loss:1124.06 Train_Acc 63.64 % Test_Acc 50.00 %
# Epoch:87/200 Train_Loss:232.50 Test_Loss:844.65 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:88/200 Train_Loss:91.86 Test_Loss:268.85 Train_Acc 90.91 % Test_Acc 83.33 %
# Epoch:89/200 Train_Loss:240.37 Test_Loss:7773.20 Train_Acc 78.79 % Test_Acc 33.33 %
# Epoch:90/200 Train_Loss:834.84 Test_Loss:1157.50 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:91/200 Train_Loss:504.36 Test_Loss:1004.14 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:92/200 Train_Loss:352.74 Test_Loss:940.64 Train_Acc 72.73 % Test_Acc 66.67 %
# Epoch:93/200 Train_Loss:166.18 Test_Loss:2227.54 Train_Acc 72.73 % Test_Acc 50.00 %
# Epoch:94/200 Train_Loss:316.70 Test_Loss:1443.36 Train_Acc 72.73 % Test_Acc 66.67 %
# Epoch:95/200 Train_Loss:271.08 Test_Loss:1447.08 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:96/200 Train_Loss:184.54 Test_Loss:814.64 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:97/200 Train_Loss:226.17 Test_Loss:856.43 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:98/200 Train_Loss:271.98 Test_Loss:1034.02 Train_Acc 69.70 % Test_Acc 58.33 %
# Epoch:99/200 Train_Loss:275.48 Test_Loss:942.21 Train_Acc 69.70 % Test_Acc 58.33 %
# Epoch:100/200 Train_Loss:301.47 Test_Loss:203.15 Train_Acc 69.70 % Test_Acc 83.33 %
# Epoch:101/200 Train_Loss:339.18 Test_Loss:850.26 Train_Acc 78.79 % Test_Acc 41.67 %
# Epoch:102/200 Train_Loss:390.52 Test_Loss:1017.38 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:103/200 Train_Loss:257.84 Test_Loss:758.62 Train_Acc 78.79 % Test_Acc 75.00 %
# Epoch:104/200 Train_Loss:98.05 Test_Loss:1049.14 Train_Acc 81.82 % Test_Acc 66.67 %
# Epoch:105/200 Train_Loss:254.13 Test_Loss:459.70 Train_Acc 78.79 % Test_Acc 83.33 %
# Epoch:106/200 Train_Loss:341.38 Test_Loss:1774.03 Train_Acc 78.79 % Test_Acc 50.00 %
# Epoch:107/200 Train_Loss:156.56 Test_Loss:330.06 Train_Acc 81.82 % Test_Acc 58.33 %
# Epoch:108/200 Train_Loss:85.75 Test_Loss:331.33 Train_Acc 93.94 % Test_Acc 75.00 %
# Epoch:109/200 Train_Loss:150.58 Test_Loss:1934.47 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:110/200 Train_Loss:367.88 Test_Loss:717.97 Train_Acc 69.70 % Test_Acc 66.67 %
# Epoch:111/200 Train_Loss:313.42 Test_Loss:1431.98 Train_Acc 75.76 % Test_Acc 50.00 %
# Epoch:112/200 Train_Loss:152.87 Test_Loss:679.11 Train_Acc 75.76 % Test_Acc 83.33 %
# Epoch:113/200 Train_Loss:403.32 Test_Loss:2929.03 Train_Acc 78.79 % Test_Acc 33.33 %
# Epoch:114/200 Train_Loss:276.21 Test_Loss:432.85 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:115/200 Train_Loss:530.36 Test_Loss:2713.40 Train_Acc 72.73 % Test_Acc 50.00 %
# Epoch:116/200 Train_Loss:231.00 Test_Loss:1184.33 Train_Acc 84.85 % Test_Acc 41.67 %
# Epoch:117/200 Train_Loss:364.25 Test_Loss:682.30 Train_Acc 72.73 % Test_Acc 66.67 %
# Epoch:118/200 Train_Loss:205.02 Test_Loss:269.03 Train_Acc 78.79 % Test_Acc 83.33 %
# Epoch:119/200 Train_Loss:174.97 Test_Loss:834.31 Train_Acc 90.91 % Test_Acc 66.67 %
# Epoch:120/200 Train_Loss:375.07 Test_Loss:1002.02 Train_Acc 63.64 % Test_Acc 58.33 %
# Epoch:121/200 Train_Loss:152.32 Test_Loss:1595.10 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:122/200 Train_Loss:223.87 Test_Loss:1109.40 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:123/200 Train_Loss:235.34 Test_Loss:3058.82 Train_Acc 78.79 % Test_Acc 41.67 %
# Epoch:124/200 Train_Loss:521.00 Test_Loss:425.57 Train_Acc 72.73 % Test_Acc 83.33 %
# Epoch:125/200 Train_Loss:205.08 Test_Loss:477.56 Train_Acc 78.79 % Test_Acc 83.33 %
# Epoch:126/200 Train_Loss:148.32 Test_Loss:377.09 Train_Acc 87.88 % Test_Acc 75.00 %
# Epoch:127/200 Train_Loss:232.91 Test_Loss:1014.19 Train_Acc 78.79 % Test_Acc 75.00 %
# Epoch:128/200 Train_Loss:156.41 Test_Loss:756.36 Train_Acc 87.88 % Test_Acc 66.67 %
# Epoch:129/200 Train_Loss:142.30 Test_Loss:1439.08 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:130/200 Train_Loss:182.68 Test_Loss:639.24 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:131/200 Train_Loss:194.11 Test_Loss:362.27 Train_Acc 75.76 % Test_Acc 75.00 %
# Epoch:132/200 Train_Loss:269.01 Test_Loss:234.01 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:133/200 Train_Loss:87.41 Test_Loss:251.16 Train_Acc 81.82 % Test_Acc 66.67 %
# Epoch:134/200 Train_Loss:112.52 Test_Loss:662.17 Train_Acc 84.85 % Test_Acc 58.33 %
# Epoch:135/200 Train_Loss:50.42 Test_Loss:286.89 Train_Acc 90.91 % Test_Acc 75.00 %
# Epoch:136/200 Train_Loss:145.74 Test_Loss:228.02 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:137/200 Train_Loss:125.31 Test_Loss:414.61 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:138/200 Train_Loss:51.03 Test_Loss:781.00 Train_Acc 96.97 % Test_Acc 50.00 %
# Epoch:139/200 Train_Loss:66.21 Test_Loss:213.63 Train_Acc 84.85 % Test_Acc 75.00 %
# Epoch:140/200 Train_Loss:254.18 Test_Loss:613.95 Train_Acc 63.64 % Test_Acc 75.00 %
# Epoch:141/200 Train_Loss:115.78 Test_Loss:282.33 Train_Acc 84.85 % Test_Acc 75.00 %
# Epoch:142/200 Train_Loss:163.93 Test_Loss:1068.19 Train_Acc 87.88 % Test_Acc 58.33 %
# Epoch:143/200 Train_Loss:99.18 Test_Loss:358.96 Train_Acc 87.88 % Test_Acc 66.67 %
# Epoch:144/200 Train_Loss:133.94 Test_Loss:323.93 Train_Acc 81.82 % Test_Acc 75.00 %
# Epoch:145/200 Train_Loss:283.23 Test_Loss:179.75 Train_Acc 84.85 % Test_Acc 75.00 %
# Epoch:146/200 Train_Loss:20.33 Test_Loss:1387.05 Train_Acc 93.94 % Test_Acc 33.33 %
# Epoch:147/200 Train_Loss:174.20 Test_Loss:645.13 Train_Acc 81.82 % Test_Acc 66.67 %
# Epoch:148/200 Train_Loss:124.19 Test_Loss:348.22 Train_Acc 90.91 % Test_Acc 58.33 %
# Epoch:149/200 Train_Loss:217.16 Test_Loss:721.34 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:150/200 Train_Loss:84.83 Test_Loss:486.17 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:151/200 Train_Loss:310.87 Test_Loss:2239.28 Train_Acc 72.73 % Test_Acc 33.33 %
# Epoch:152/200 Train_Loss:388.84 Test_Loss:540.80 Train_Acc 60.61 % Test_Acc 66.67 %
# Epoch:153/200 Train_Loss:140.22 Test_Loss:848.95 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:154/200 Train_Loss:146.66 Test_Loss:284.09 Train_Acc 87.88 % Test_Acc 58.33 %
# Epoch:155/200 Train_Loss:129.13 Test_Loss:572.47 Train_Acc 90.91 % Test_Acc 66.67 %
# Epoch:156/200 Train_Loss:211.96 Test_Loss:696.21 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:157/200 Train_Loss:66.39 Test_Loss:327.23 Train_Acc 87.88 % Test_Acc 58.33 %
# Epoch:158/200 Train_Loss:103.39 Test_Loss:459.41 Train_Acc 72.73 % Test_Acc 66.67 %
# Epoch:159/200 Train_Loss:167.96 Test_Loss:281.91 Train_Acc 81.82 % Test_Acc 75.00 %
# Epoch:160/200 Train_Loss:220.51 Test_Loss:1231.61 Train_Acc 78.79 % Test_Acc 41.67 %
# Epoch:161/200 Train_Loss:172.97 Test_Loss:1459.98 Train_Acc 84.85 % Test_Acc 41.67 %
# Epoch:162/200 Train_Loss:212.36 Test_Loss:609.15 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:163/200 Train_Loss:243.27 Test_Loss:196.66 Train_Acc 81.82 % Test_Acc 75.00 %
# Epoch:164/200 Train_Loss:130.46 Test_Loss:848.68 Train_Acc 90.91 % Test_Acc 58.33 %
# Epoch:165/200 Train_Loss:141.59 Test_Loss:1123.40 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:166/200 Train_Loss:345.12 Test_Loss:163.77 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:167/200 Train_Loss:226.20 Test_Loss:1256.01 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:168/200 Train_Loss:103.71 Test_Loss:373.33 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:169/200 Train_Loss:216.28 Test_Loss:116.81 Train_Acc 75.76 % Test_Acc 83.33 %
# Epoch:170/200 Train_Loss:184.81 Test_Loss:1201.80 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:171/200 Train_Loss:391.20 Test_Loss:978.05 Train_Acc 60.61 % Test_Acc 66.67 %
# Epoch:172/200 Train_Loss:225.50 Test_Loss:1635.88 Train_Acc 75.76 % Test_Acc 41.67 %
# Epoch:173/200 Train_Loss:287.63 Test_Loss:345.89 Train_Acc 75.76 % Test_Acc 83.33 %
# Epoch:174/200 Train_Loss:238.28 Test_Loss:793.64 Train_Acc 72.73 % Test_Acc 58.33 %
# Epoch:175/200 Train_Loss:57.58 Test_Loss:511.62 Train_Acc 84.85 % Test_Acc 50.00 %
# Epoch:176/200 Train_Loss:127.86 Test_Loss:668.17 Train_Acc 81.82 % Test_Acc 58.33 %
# Epoch:177/200 Train_Loss:55.76 Test_Loss:742.15 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:178/200 Train_Loss:107.69 Test_Loss:374.33 Train_Acc 87.88 % Test_Acc 75.00 %
# Epoch:179/200 Train_Loss:115.90 Test_Loss:180.88 Train_Acc 87.88 % Test_Acc 83.33 %
# Epoch:180/200 Train_Loss:100.39 Test_Loss:694.98 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:181/200 Train_Loss:105.40 Test_Loss:245.73 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:182/200 Train_Loss:57.62 Test_Loss:454.02 Train_Acc 90.91 % Test_Acc 66.67 %
# Epoch:183/200 Train_Loss:144.80 Test_Loss:437.19 Train_Acc 84.85 % Test_Acc 75.00 %
# Epoch:184/200 Train_Loss:115.52 Test_Loss:209.32 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:185/200 Train_Loss:127.24 Test_Loss:536.78 Train_Acc 84.85 % Test_Acc 58.33 %
# Epoch:186/200 Train_Loss:155.83 Test_Loss:259.94 Train_Acc 84.85 % Test_Acc 83.33 %
# Epoch:187/200 Train_Loss:20.47 Test_Loss:445.42 Train_Acc 93.94 % Test_Acc 66.67 %
# Epoch:188/200 Train_Loss:105.95 Test_Loss:553.05 Train_Acc 84.85 % Test_Acc 66.67 %
# Epoch:189/200 Train_Loss:71.00 Test_Loss:1292.91 Train_Acc 87.88 % Test_Acc 50.00 %
# Epoch:190/200 Train_Loss:158.23 Test_Loss:427.05 Train_Acc 78.79 % Test_Acc 66.67 %
# Epoch:191/200 Train_Loss:62.54 Test_Loss:690.47 Train_Acc 93.94 % Test_Acc 50.00 %
# Epoch:192/200 Train_Loss:83.27 Test_Loss:500.71 Train_Acc 87.88 % Test_Acc 83.33 %
# Epoch:193/200 Train_Loss:204.34 Test_Loss:203.55 Train_Acc 72.73 % Test_Acc 75.00 %
# Epoch:194/200 Train_Loss:137.01 Test_Loss:672.14 Train_Acc 72.73 % Test_Acc 50.00 %
# Epoch:195/200 Train_Loss:125.37 Test_Loss:577.94 Train_Acc 75.76 % Test_Acc 66.67 %
# Epoch:196/200 Train_Loss:198.22 Test_Loss:1079.17 Train_Acc 81.82 % Test_Acc 41.67 %
# Epoch:197/200 Train_Loss:171.39 Test_Loss:173.78 Train_Acc 78.79 % Test_Acc 58.33 %
# Epoch:198/200 Train_Loss:98.71 Test_Loss:528.14 Train_Acc 81.82 % Test_Acc 50.00 %
# Epoch:199/200 Train_Loss:99.96 Test_Loss:749.00 Train_Acc 90.91 % Test_Acc 66.67 %
# Epoch:200/200 Train_Loss:241.36 Test_Loss:104.60 Train_Acc 75.76 % Test_Acc 66.67 %
# Text(0.5, 24.0, 'Predicted label')

# %%
testl_f,tl_f,testa_f,ta_f=[],[],[],[]


tl_f.append(np.mean(l_a['train_loss']))
testl_f.append(np.mean(l_a['test_loss']))

ta_f.append(np.mean(l_a['train_acc']))
testa_f.append(np.mean(l_a['test_acc']))
print("Avg Training Loss: {:.3f} \t Avg Test Loss: {:.3f} \t Avg Training Acc: {:.2f} \t Avg Test Acc: {:.2f}".format(np.mean(tl_f),np.mean(testl_f),np.mean(ta_f),np.mean(testa_f)))
# Out:
# Avg Training Loss: 382.644 	 Avg Test Loss: 1310.824 	 Avg Training Acc: 77.47 	 Avg Test Acc: 61.62

# %%
plt.figure(figsize=(10,8))
plt.semilogy(l_a['train_loss'], label='Train')
plt.semilogy(l_a['test_loss'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.grid()
plt.legend()
plt.title('3D_CNN loss')
plt.show()

# Plot accuracies
plt.figure(figsize=(10,8))
plt.semilogy(l_a['train_acc'], label='Train')
plt.semilogy(l_a['test_acc'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.grid()
plt.legend()
plt.title('3D_CNN accuracy')
plt.show()
